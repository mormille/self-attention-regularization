# %%
from torchvision import datasets, transforms, models
import torch.optim as optim
from torch.optim import lr_scheduler
import time
import os
import copy
import torchvision.transforms as T
import torch

from PIL import Image
import requests

import matplotlib.pyplot as plt
import numpy as np
import torch.nn.functional as F
from torch import nn
from torch.optim import lr_scheduler

from torchsummary import summary

import skimage
import skimage.transform

# %%
from models.backbone import Backbone
from models.encoder import EncoderModule
from models.joiner import Joiner
from models.losses import Attention_penalty_factor, Generator_loss
from models.unet import UNet
from training import fit_adversarial

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
H = 180
W=180

transform = T.Compose([
T.Resize((H,W)),
T.ToTensor(),
T.Normalize([0.485, 0.456, 0.406], [0.485, 0.456, 0.406]),
#T.Grayscale(num_output_channels=3)
])

transform2 = T.Compose([
T.Resize((H,W)),
T.ToTensor()
])

# %%
train_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
val_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
tr_split_len = 50000
vl_split_len = 10000
training_dataset = torch.utils.data.random_split(train_dataset, [tr_split_len, len(train_dataset)-tr_split_len])[0]
validation_dataset = torch.utils.data.random_split(val_dataset, [vl_split_len, len(val_dataset)-vl_split_len])[0]

# %%
training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=10, shuffle=True)
validation_loader = torch.utils.data.DataLoader(validation_dataset, batch_size = 10, shuffle=False)

# %%
def add_noise(inputs):
    noise = torch.randn_like(inputs)*0.2
    return inputs + noise

# %%
def im_convert(tensor):
    image = tensor.cpu().clone().detach().numpy()
    image = image.transpose(1, 2, 0)
    image = image * np.array((0.5, 0.5, 0.5)) + np.array((0.5, 0.5, 0.5))
    image = image.clip(0, 1)
    return image

# %%
dataiter = iter(training_loader)
images, labels = dataiter.next()
images = add_noise(images)
fig = plt.figure(figsize=(25, 4))

for idx in np.arange(10):
  ax = fig.add_subplot(2, 10, idx+1, xticks=[], yticks=[])
  plt.imshow(im_convert(images[idx]))
  ax.set_title([labels[idx].item()])

# %%
cifar_img = training_dataset[4][0].unsqueeze(0)
#unet = UNet(3,3)
backbone = Backbone().to(device)
encoder = EncoderModule().to(device)
model = Joiner(backbone, encoder, hidden_dim=512, image_h=H, image_w=W)

# %%
model = model.to(device)

# %%
#TESTING MODEL ON A SINGLE IMAGE

# %%
url = 'https://ogden_images.s3.amazonaws.com/www.timesrepublican.com/images/2019/05/02231710/Fox-WEB-1100x739.jpg'

im = Image.open(requests.get(url, stream=True).raw)

# %%
img = transform2(im).unsqueeze(0)
print("Input shape:", img.shape)
# Out:
# Input shape: torch.Size([1, 3, 180, 180])

# %%
noised_img = add_noise(img)

# %%
plt.subplot(221)
plt.imshow(img[0].permute(1, 2, 0))
plt.subplot(222)
plt.imshow(noised_img[0].detach().permute(1, 2, 0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
outputs, sattn, pattn = model(img.to(device))
outputs_cifar, sattn_cifar, pattn_cifar = model(img.to(device))

# %%
print("Output shape:", outputs.shape)
#print("Feature Map shape:", f_map.shape)
print("Attention Maps shape:", sattn.shape)
#print("Encoder output shape:", att.shape)
#print("Positional Encoding shape:", pos.shape)
# Out:
# Output shape: torch.Size([1, 10])
# Attention Maps shape: torch.Size([1, 12, 12, 12, 12])

# %%
#Training Model

# %%
model_criterion = nn.CrossEntropyLoss()
model_optimizer = torch.optim.Adam(model.parameters(), lr = 0.0001)
model_lr_scheduler = lr_scheduler.StepLR(model_optimizer, step_size=10, gamma=0.1)

# %%
def train_model_rn(model, inputs, labels, opt_d, model_criterion):
    
    
    # Clear discriminator gradients
    opt_d.zero_grad()
    
    real_inputs = inputs.to(device) # allow gpu use
    labels = labels.to(device) # allow gpu use
    # Pass real images through model
    real_preds, sattn, pattn = model(real_inputs)
    real_loss = model_criterion(real_preds, labels)
    real_score = torch.mean(real_preds).item()
    
    _, preds = torch.max(real_preds, 1) # return the index of the maximum value predicted for that image (used to generate the accuracy)
     # the sum of the loss of all itens
    running_corrects = torch.sum(preds == labels.data) # the sum of correct prediction on an epochs
    #print("TRAIN MODEL FUNCTION - RUNNING CORRECTS",running_corrects)
    
    # Generate fake images
    noised_inputs = add_noise(real_inputs)

    # Pass fake images through discriminator
    noised_preds, noised_sattn, noised_pattn = model(noised_inputs)
    noised_loss = model_criterion(noised_preds, labels)
    noised_score = torch.mean(noised_preds).item()
    
    _, preds_noised = torch.max(noised_preds, 1)
    running_noised_corrects = torch.sum(preds_noised == labels.data)
    #print("TRAIN MODEL FUNCTION - RUNNING NOISED CORRECTS",running_noised_corrects)

    # Update discriminator weights
    loss = real_loss + noised_loss
    loss.backward()
    opt_d.step()
    return loss.item(), real_score, noised_score, running_corrects, running_noised_corrects, sattn, noised_sattn

# %%
def fit_random_noise(training_loader, validation_loader, model, model_criterion, model_optimizer, 
    model_lr_scheduler, len_train, len_val, 
    path='test/TOP_PERFORMANCE_epoch_', epochs=25, start_idx=1):
    
    torch.cuda.empty_cache()
    
    # Losses & scores
    losses_d = []
    real_scores = []
    noise_scores = []
    real_corrects = []
    noised_corrects = []
    val_real_corrects = []
    val_noised_corrects = []
    train_real_attention_maps = []
    train_adversarial_attention_maps = []
    val_real_attention_maps = []
    val_adversarial_attention_maps = []
    
    best_model_wts = copy.deepcopy(model.state_dict())
    
    since = time.time()

    best_model_wts = copy.deepcopy(model.state_dict())
    best_acc = 0.0
    
    for epoch in range(epochs):
        start_time = time.time()
        print('Epoch {}/{}'.format(epoch+1, epochs))
        print('-' * 10)
        
        running_loss = 0.0
        running_real_corrects = 0.0
        running_noised_corrects = 0.0
        val_running_loss = 0.0
        val_running_real_corrects = 0.0
        val_running_noised_corrects = 0.0

        
        for inputs, labels in training_loader:
            # Train discriminator
            loss_d, real_score, noise_score, real_pred, noised_pred, sattn, noised_sattn = train_model_rn(model, inputs, labels, model_optimizer, model_criterion)
            running_real_corrects +=real_pred
            running_noised_corrects +=noised_pred
            #print("FIT FUNCTION - RUNNING REAL CORRECTS",running_real_corrects.item())
            #print("FIT FUNCTION - RUNNING NOISED CORRECTS",running_noised_corrects.item())
            

        else:
        #VALIDATION
            with torch.no_grad(): # to save memory (temporalely set all the requires grad to be false)
                for val_inputs, val_labels in validation_loader:
                    val_inputs = val_inputs.to(device) # allow gpu use
                    val_labels = val_labels.to(device) # allow gpu use
                    val_noised_input = add_noise(val_inputs) #passes the image through the network and get the output
                    val_preds_real, val_real_sattn, val_real_pattn = model(val_inputs)
                    val_preds_noised, val_noised_sattn, val_noised_pattn = model(val_noised_input)
                    val_real_loss = model_criterion(val_preds_real, val_labels) #compare output and labels to get the loss 
                    val_noised_loss = model_criterion(val_preds_noised, val_labels)
                    
                    _, val_real_preds = torch.max(val_preds_real, 1) #same as for training
                    _, val_noised_preds = torch.max(val_preds_noised, 1) #same as for training
                    
                    val_loss = val_real_loss + val_noised_loss
                    val_running_real_corrects += torch.sum(val_real_preds == val_labels.data) #same as for training
                    val_running_noised_corrects += torch.sum(val_noised_preds == val_labels.data) #same as for training
        
        model_lr_scheduler.step()

        # Record losses & scores
        losses_d.append(loss_d)
        real_scores.append(real_score)
        noise_scores.append(noise_score)
        real_corrects.append(running_real_corrects)
        noised_corrects.append(running_noised_corrects)
        val_real_corrects.append(val_running_real_corrects)
        val_noised_corrects.append(val_running_noised_corrects)
        train_real_attention_maps.append(sattn)
        train_adversarial_attention_maps.append(noised_sattn)
        val_real_attention_maps.append(val_real_sattn)
        val_adversarial_attention_maps.append(val_noised_sattn)
        
        # Log losses & scores (last batch)
        print("Epoch [{}/{}], loss_d: {:.4f}, real_score: {:.4f}, noised_score: {:.4f}".format(
            epoch+1, epochs, loss_d, real_score, noise_score))
    
    
        # Model accuracy       
        print("EPOCH RUNNING REAL CORRECT PREDICTIONS",running_real_corrects.item())
        print("EPOCH RUNNING NOISED CORRECTS PREDICTIONS",running_noised_corrects.item())
        epoch_real_acc = running_real_corrects.item()/ len_train
        epoch_noised_acc = running_noised_corrects.item()/ len_train
        print("Epoch [{}/{}], Training - real acc: {:.4f}, noised acc: {:.4f}".format(
            epoch+1, epochs, epoch_real_acc, epoch_noised_acc))
        
        val_epoch_real_acc = val_running_real_corrects.float()/ len_val
        val_epoch_noised_acc = val_running_noised_corrects.float()/ len_val
        print("Epoch [{}/{}], Validation - real acc: {:.4f}, noised acc: {:.4f}".format(
            epoch+1, epochs, val_epoch_real_acc, val_epoch_noised_acc))
              
        # Save generated images
        #save_samples(epoch+start_idx, fixed_latent, show=False)
        
        
        epoch_time_elapsed = time.time() - start_time
        print('Epoch training complete in {:.0f}m {:.0f}s'.format(
            epoch_time_elapsed // 60, epoch_time_elapsed % 60))

        if val_epoch_real_acc > best_acc:
                best_acc = val_epoch_real_acc
                best_model_wts = copy.deepcopy(model.state_dict())
                print("TOP PERFORMANCE UPDATED")
                            
    time_elapsed = time.time() - since
    print('Training complete in {:.0f}m {:.0f}s'.format(
        time_elapsed // 60, time_elapsed % 60))
    print('Best val Acc: {:4f}'.format(best_acc))
    
    model.load_state_dict(best_model_wts)
    torch.save(model.state_dict(),path + str(epoch) + '.pth')
    
    return losses_d, real_corrects, noised_corrects, val_real_corrects, val_noised_corrects,train_real_attention_maps, train_adversarial_attention_maps, val_real_attention_maps, val_adversarial_attention_maps

# %%
random_noise_training = fit_random_noise(training_loader, validation_loader, model, model_criterion, model_optimizer, 
    model_lr_scheduler, len_train=len(training_dataset), len_val=len(validation_dataset), 
    path='test/RAMDOM_NOISE_TOP_PERFORMANCE_epoch_', epochs=25, start_idx=1)
# Out:
# Epoch 1/25
# ----------
# Epoch [1/25], loss_d: 4.7355, real_score: 0.7359, noised_score: 0.7683
# EPOCH RUNNING REAL CORRECT PREDICTIONS 16036.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 15396.0
# Epoch [1/25], Training - real acc: 0.3207, noised acc: 0.3079
# Epoch [1/25], Validation - real acc: 0.4225, noised acc: 0.4116
# Epoch training complete in 19m 40s
# TOP PERFORMANCE UPDATED
# Epoch 2/25
# ----------
# Epoch [2/25], loss_d: 3.8186, real_score: 0.4581, noised_score: 0.4696
# EPOCH RUNNING REAL CORRECT PREDICTIONS 22946.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 22297.0
# Epoch [2/25], Training - real acc: 0.4589, noised acc: 0.4459
# Epoch [2/25], Validation - real acc: 0.4959, noised acc: 0.4954
# Epoch training complete in 19m 39s
# TOP PERFORMANCE UPDATED
# Epoch 3/25
# ----------
# Epoch [3/25], loss_d: 1.4871, real_score: 0.4779, noised_score: 0.4011
# EPOCH RUNNING REAL CORRECT PREDICTIONS 28090.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 27990.0
# Epoch [3/25], Training - real acc: 0.5618, noised acc: 0.5598
# Epoch [3/25], Validation - real acc: 0.6159, noised acc: 0.6153
# Epoch training complete in 19m 35s
# TOP PERFORMANCE UPDATED
# Epoch 4/25
# ----------
# Epoch [4/25], loss_d: 1.2546, real_score: 0.1950, noised_score: 0.2323
# EPOCH RUNNING REAL CORRECT PREDICTIONS 33784.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 33470.0
# Epoch [4/25], Training - real acc: 0.6757, noised acc: 0.6694
# Epoch [4/25], Validation - real acc: 0.6780, noised acc: 0.6675
# Epoch training complete in 19m 35s
# TOP PERFORMANCE UPDATED
# Epoch 5/25
# ----------
# Epoch [5/25], loss_d: 2.3933, real_score: 0.0615, noised_score: 0.0921
# EPOCH RUNNING REAL CORRECT PREDICTIONS 36547.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 36316.0
# Epoch [5/25], Training - real acc: 0.7309, noised acc: 0.7263
# Epoch [5/25], Validation - real acc: 0.6903, noised acc: 0.6919
# Epoch training complete in 19m 35s
# TOP PERFORMANCE UPDATED
# Epoch 6/25
# ----------
# Epoch [6/25], loss_d: 1.0033, real_score: -0.0130, noised_score: -0.0143
# EPOCH RUNNING REAL CORRECT PREDICTIONS 38996.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 38814.0
# Epoch [6/25], Training - real acc: 0.7799, noised acc: 0.7763
# Epoch [6/25], Validation - real acc: 0.7370, noised acc: 0.7397
# Epoch training complete in 19m 34s
# TOP PERFORMANCE UPDATED
# Epoch 7/25
# ----------
# Epoch [7/25], loss_d: 1.4759, real_score: 0.0490, noised_score: 0.0425
# EPOCH RUNNING REAL CORRECT PREDICTIONS 40585.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 40283.0
# Epoch [7/25], Training - real acc: 0.8117, noised acc: 0.8057
# Epoch [7/25], Validation - real acc: 0.7424, noised acc: 0.7361
# Epoch training complete in 19m 37s
# TOP PERFORMANCE UPDATED
# Epoch 8/25
# ----------
# Epoch [8/25], loss_d: 0.9554, real_score: -0.1574, noised_score: -0.1586
# EPOCH RUNNING REAL CORRECT PREDICTIONS 41338.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 41058.0
# Epoch [8/25], Training - real acc: 0.8268, noised acc: 0.8212
# Epoch [8/25], Validation - real acc: 0.7121, noised acc: 0.7091
# Epoch training complete in 19m 36s
# Epoch 9/25
# ----------
# Epoch [9/25], loss_d: 0.8355, real_score: -0.2071, noised_score: -0.2098
# EPOCH RUNNING REAL CORRECT PREDICTIONS 43866.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 43585.0
# Epoch [9/25], Training - real acc: 0.8773, noised acc: 0.8717
# Epoch [9/25], Validation - real acc: 0.7293, noised acc: 0.7220
# Epoch training complete in 19m 38s
# Epoch 10/25
# ----------
# Epoch [10/25], loss_d: 0.4953, real_score: -0.2551, noised_score: -0.2321
# EPOCH RUNNING REAL CORRECT PREDICTIONS 44688.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 44324.0
# Epoch [10/25], Training - real acc: 0.8938, noised acc: 0.8865
# Epoch [10/25], Validation - real acc: 0.7280, noised acc: 0.7277
# Epoch training complete in 19m 37s
# Epoch 11/25
# ----------
# Epoch [11/25], loss_d: 0.0296, real_score: -0.3893, noised_score: -0.4068
# EPOCH RUNNING REAL CORRECT PREDICTIONS 48618.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 48392.0
# Epoch [11/25], Training - real acc: 0.9724, noised acc: 0.9678
# Epoch [11/25], Validation - real acc: 0.7741, noised acc: 0.7636
# Epoch training complete in 19m 37s
# TOP PERFORMANCE UPDATED
# Epoch 12/25
# ----------
# Epoch [12/25], loss_d: 0.0483, real_score: -0.4056, noised_score: -0.3977
# EPOCH RUNNING REAL CORRECT PREDICTIONS 49482.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 49287.0
# Epoch [12/25], Training - real acc: 0.9896, noised acc: 0.9857
# Epoch [12/25], Validation - real acc: 0.7740, noised acc: 0.7666
# Epoch training complete in 19m 38s
# Epoch 13/25
# ----------
# Epoch [13/25], loss_d: 0.0023, real_score: -0.2716, noised_score: -0.2756
# EPOCH RUNNING REAL CORRECT PREDICTIONS 49789.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 49670.0
# Epoch [13/25], Training - real acc: 0.9958, noised acc: 0.9934
# Epoch [13/25], Validation - real acc: 0.7774, noised acc: 0.7696
# Epoch training complete in 19m 38s
# TOP PERFORMANCE UPDATED
# Epoch 14/25
# ----------
# Epoch [14/25], loss_d: 0.0006, real_score: -0.4349, noised_score: -0.4157
# EPOCH RUNNING REAL CORRECT PREDICTIONS 49877.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 49758.0
# Epoch [14/25], Training - real acc: 0.9975, noised acc: 0.9952
# Epoch [14/25], Validation - real acc: 0.7783, noised acc: 0.7714
# Epoch training complete in 19m 38s
# TOP PERFORMANCE UPDATED
# Epoch 15/25
# ----------
# Epoch [15/25], loss_d: 0.0016, real_score: -0.5057, noised_score: -0.4894
# EPOCH RUNNING REAL CORRECT PREDICTIONS 49918.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 49838.0
# Epoch [15/25], Training - real acc: 0.9984, noised acc: 0.9968
# Epoch [15/25], Validation - real acc: 0.7760, noised acc: 0.7730
# Epoch training complete in 19m 37s
# Epoch 16/25
# ----------
# Epoch [16/25], loss_d: 0.0000, real_score: -0.5735, noised_score: -0.5225
# EPOCH RUNNING REAL CORRECT PREDICTIONS 49942.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 49866.0
# Epoch [16/25], Training - real acc: 0.9988, noised acc: 0.9973
# Epoch [16/25], Validation - real acc: 0.7802, noised acc: 0.7780
# Epoch training complete in 19m 38s
# TOP PERFORMANCE UPDATED
# Epoch 17/25
# ----------
# Epoch [17/25], loss_d: 0.0202, real_score: -0.4100, noised_score: -0.4236
# EPOCH RUNNING REAL CORRECT PREDICTIONS 49952.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 49879.0
# Epoch [17/25], Training - real acc: 0.9990, noised acc: 0.9976
# Epoch [17/25], Validation - real acc: 0.7776, noised acc: 0.7730
# Epoch training complete in 19m 36s
# Epoch 18/25
# ----------
# Epoch [18/25], loss_d: 0.0011, real_score: -0.6839, noised_score: -0.6711
# EPOCH RUNNING REAL CORRECT PREDICTIONS 49956.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 49893.0
# Epoch [18/25], Training - real acc: 0.9991, noised acc: 0.9979
# Epoch [18/25], Validation - real acc: 0.7772, noised acc: 0.7716
# Epoch training complete in 19m 37s
# Epoch 19/25
# ----------
# Epoch [19/25], loss_d: 0.0007, real_score: -0.6438, noised_score: -0.6405
# EPOCH RUNNING REAL CORRECT PREDICTIONS 49971.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 49912.0
# Epoch [19/25], Training - real acc: 0.9994, noised acc: 0.9982
# Epoch [19/25], Validation - real acc: 0.7795, noised acc: 0.7727
# Epoch training complete in 19m 37s
# Epoch 20/25
# ----------
# Epoch [20/25], loss_d: 0.0005, real_score: -0.8865, noised_score: -0.8365
# EPOCH RUNNING REAL CORRECT PREDICTIONS 49963.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 49916.0
# Epoch [20/25], Training - real acc: 0.9993, noised acc: 0.9983
# Epoch [20/25], Validation - real acc: 0.7777, noised acc: 0.7712
# Epoch training complete in 19m 38s
# Epoch 21/25
# ----------
# Epoch [21/25], loss_d: 0.0009, real_score: -0.8414, noised_score: -0.8144
# EPOCH RUNNING REAL CORRECT PREDICTIONS 49994.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 49963.0
# Epoch [21/25], Training - real acc: 0.9999, noised acc: 0.9993
# Epoch [21/25], Validation - real acc: 0.7800, noised acc: 0.7781
# Epoch training complete in 19m 38s
# Epoch 22/25
# ----------
# Epoch [22/25], loss_d: 0.0008, real_score: -0.4714, noised_score: -0.4575
# EPOCH RUNNING REAL CORRECT PREDICTIONS 49991.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 49969.0
# Epoch [22/25], Training - real acc: 0.9998, noised acc: 0.9994
# Epoch [22/25], Validation - real acc: 0.7804, noised acc: 0.7737
# Epoch training complete in 19m 36s
# TOP PERFORMANCE UPDATED
# Epoch 23/25
# ----------
# Epoch [23/25], loss_d: 0.0001, real_score: -0.8104, noised_score: -0.8407
# EPOCH RUNNING REAL CORRECT PREDICTIONS 49994.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 49968.0
# Epoch [23/25], Training - real acc: 0.9999, noised acc: 0.9994
# Epoch [23/25], Validation - real acc: 0.7798, noised acc: 0.7756
# Epoch training complete in 19m 34s
# Epoch 24/25
# ----------
# Epoch [24/25], loss_d: 0.0017, real_score: -0.8487, noised_score: -0.8290
# EPOCH RUNNING REAL CORRECT PREDICTIONS 49999.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 49980.0
# Epoch [24/25], Training - real acc: 1.0000, noised acc: 0.9996
# Epoch [24/25], Validation - real acc: 0.7813, noised acc: 0.7753
# Epoch training complete in 19m 37s
# TOP PERFORMANCE UPDATED
# Epoch 25/25
# ----------
# Epoch [25/25], loss_d: 0.0011, real_score: -0.8380, noised_score: -0.8150
# EPOCH RUNNING REAL CORRECT PREDICTIONS 49996.0
# EPOCH RUNNING NOISED CORRECTS PREDICTIONS 49981.0
# Epoch [25/25], Training - real acc: 0.9999, noised acc: 0.9996
# Epoch [25/25], Validation - real acc: 0.7823, noised acc: 0.7760
# Epoch training complete in 19m 38s
# TOP PERFORMANCE UPDATED
# Training complete in 490m 23s
# Best val Acc: 0.782300

# %%
real_accuracy = []
noised_accuracy = []
for i in range(len(random_noise_training[1])):
    real_accuracy.append(random_noise_training[1][i]/len(training_dataset))
    noised_accuracy.append(random_noise_training[2][i]/len(training_dataset))

# %%
val_real_accuracy = []
val_noised_accuracy = []
for i in range(len(random_noise_training[1])):
    val_real_accuracy.append(random_noise_training[3][i]/len(validation_dataset))
    val_noised_accuracy.append(random_noise_training[4][i]/len(validation_dataset))

# %%
training_accuracy = []
validation_accuracy = []
for i in range(len(random_noise_training[1])):
    training_accuracy.append((random_noise_training[1][i]+random_noise_training[2][i])/len(training_dataset)*2)
    validation_accuracy.append((random_noise_training[3][i]+random_noise_training[4][i])/len(validation_dataset)*2)

# %%
plt.plot()
plt.plot(random_noise_training[0],color="g")
plt.xlabel("Epoch")
plt.ylabel("Model Loss")
# Out:
# Text(0, 0.5, 'Model Loss')

# %%
plt.plot()
plt.plot(real_accuracy,color="r",)
plt.plot(noised_accuracy,color="b")
plt.xlabel("Epoch")
plt.ylabel("Training accuracy")
# Out:
# Text(0, 0.5, 'Training accuracy')

# %%
plt.plot()
plt.plot(val_real_accuracy,color="r",)
plt.plot(val_noised_accuracy,color="b")
plt.xlabel("Epoch")
plt.ylabel("Validation accuracy")
# Out:
# Text(0, 0.5, 'Validation accuracy')

# %%
plt.plot()
plt.plot(training_accuracy,color="g",)
plt.plot(validation_accuracy,color="r")
plt.xlabel("Epoch")
plt.ylabel("Training vs Validation accuracy")
# Out:
# Text(0, 0.5, 'Training vs Validation accuracy')

# %%
cifar_img = cifar_img.to(device)
cifar_noised = add_noise(cifar_img)
outputs2, sattn2, pattn2 = model(cifar_img)
outputs_noised, sattn_noised, pattn_noised = model(cifar_noised)

# %%
pix_h = 11
pix_w = 0
plt.subplot(221)
plt.imshow(cifar_img[0].cpu().permute(1, 2, 0))
plt.subplot(222)
plt.imshow(cifar_noised[0].cpu().detach().permute(1, 2, 0))
plt.subplot(223)
plt.imshow(sattn2[0,pix_h,pix_w,...].cpu().detach().numpy())
plt.subplot(224)
plt.imshow(sattn_noised[0,pix_h,pix_w,...].cpu().detach().numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
