# %%
from fastai.vision.all import *
from fastai.distributed import *
from fastai.vision.gan import *
from fastai.callback.tracker import SaveModelCallback
from fastprogress import fastprogress
import torch
import argparse
from models.utils.gan_joiner import GAN
from models.utils.losses import *
from models.utils.metrics import *
from models.utils.misc import *
from models.unet import UNet
from models.utils.datasets import *

from torchvision import datasets, transforms, models
import torchvision.transforms as T

# %%
from fastai import torch_core

# %%
H = 320
W= 320
bs = 5
nclass = 4
seed = 1234
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)

# %%
#transform = T.Compose([
#T.Resize((H,W)),
#T.ToTensor(),
#T.Normalize([0.485, 0.456, 0.406], [0.485, 0.456, 0.406])
#])

# %%
path = './data/ImageNetRotation1k/'

transform = ([*aug_transforms(),Normalize.from_stats([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])])

data = DataBlock(blocks=(ImageBlock, CategoryBlock), 
                 get_items=get_image_files, 
                 splitter=RandomSplitter(),
                 get_y=parent_label,
                 item_tfms=Resize(H,W),
                 batch_tfms=transform)

dloader = data.dataloaders(path,bs=bs)

# %%
GanLoss = GanLossWrapper(beta=0, gamma=0.005,sigma=1)

gan = GAN(num_encoder_layers = 4, nhead=4, backbone = True, num_classes = nclass, bypass=False, hidden_dim=256, 
          batch_size=bs, image_h=H, image_w=W,grid_l=4,penalty_factor="2")

# %%
gan.generatorSwitcher()
gan.noiseSwitcher()
print("Noise mode:", gan.noise_mode)
print("Generator mode:", gan.generator_mode)
# Out:
# Noise mode: False
# Generator mode: False

# %%
gan.paramsToUpdate()
gan.assertParams()

# %%
def alt_load(self:Learner, file, with_opt=None, device=None, **kwargs):
    if device is None and hasattr(self.dls, 'device'): device = self.dls.device
    if with_opt is None: self.opt=None
    file = join_path_file(file, self.path/self.model_dir, ext='.pth')
    load_model(file, self.model, self.opt, device=device, **kwargs)
    return self
Learner.load = alt_load

# %%
def alt_create_opt(self):
    self.opt = self.opt_func(self.splitter(self.model), lr=self.lr)
    if not self.wd_bn_bias:
        #print("Param update")
        for p in self._bn_bias_state(True ): p['do_wd'] = False
    if self.train_bn:
        #print("Param update again")
        for p in self._bn_bias_state(False): p['force_train'] = True
            
def params(m):
    "Return all parameters of `m`"
    return [p for p in m.parameters()]

# Cell
def gan_trainable_params(m):
    #print("Gan trainable parameters update")
    "Return all trainable parameters of `m`"
    if m.generator_mode == True:
        m.noise_mode = True
        for param in m.generator.parameters():
            param.requires_grad = True
        for param in m.model.parameters():
            param.requires_grad = False
    else:
        for param in m.generator.parameters():
            param.requires_grad = False
        for name, param in m.model.named_parameters():
            fb = ["mask","penalty_mask","pos"]
            if name not in fb:
                param.requires_grad = True
            else:
                param.requires_grad = False
    return [p for p in m.parameters() if p.requires_grad]

#torch_core.trainable_params = gan_trainable_params
Learner.create_opt = alt_create_opt

# %%
def _do_generator_epoch(self):
    
    for param in self.model.generator.parameters():
        param.requires_grad = True
    for param in self.model.model.parameters():
        param.requires_grad = False
     
    self.model.noise_mode = True
    #self.loss_func.generator_mode = True
    
    self.model.generator_mode = True
    
    self.create_opt()
    
    #checkParam = ["generator.down1.maxpool_conv.1.double_conv.0.weight","model.penalty_mask","model.encoder.encoder.layers.0.self_attn.out_proj.bias"]
#     checkParam = ["model.encoder.encoder.layers.0.self_attn.out_proj.weight"]
#     for name, p in self.model.named_parameters(): 
#         if name in checkParam:
#             print(p, p.requires_grad)
    
    self._do_epoch_train()
    self._do_epoch_validate()
    
    #self.model.generator_mode = False
    
def _do_noise_critic_epoch(self):
    
    for param in self.model.generator.parameters():
        param.requires_grad = False
    fb = ["mask","penalty_mask","pos"]
    for name, p in self.model.model.named_parameters(): 
        if name not in fb:
            p.requires_grad_(True)

    self.loss_func.generator_mode = False

    self.model.noise_mode = True
    
    self.model.generator_mode = False
    self.create_opt()
    
    checkParam = ["model.backbone.backbone.layer1.1.bn2.weight"]
    for name, p in self.model.named_parameters(): 
        if name in checkParam:
            print(p, p.requires_grad)
    
    self._do_epoch_train()
    self._do_epoch_validate()
    
    #self.model.generator_mode = True
    
def _do_critic_epoch(self):
    
    for param in self.model.generator.parameters():
        param.requires_grad = False
    fb = ["mask","penalty_mask","pos"]
    for name, p in self.model.model.named_parameters(): 
        if name not in fb:
            p.requires_grad_(True)

    self.loss_func.generator_mode = False
    self.model.noise_mode = False
    self.model.generator_mode = False
    
    self.create_opt()
#     checkParam = ["model.encoder.encoder.layers.0.self_attn.out_proj.weight"]
#     for name, p in self.model.named_parameters(): 
#         if name in checkParam:
#             print(p, p.requires_grad)

    self._do_epoch_train()
    self._do_epoch_validate()

def _GAN_do_fit(self):
    if self.model.generator_mode == True:
        for epoch in range(self.n_epoch):
            self.epoch=epoch
            #Generator Training
            self.opt.set_hypers(lr=self.generator_lr)
            self.lr=self.generator_lr
            #print(self.lr)
            self.loss_func.generator_mode = True
            self._with_events(self._do_generator_epoch, 'epoch', CancelEpochException)

            #Critic Training
            self.opt.set_hypers(lr=self.critic_lr)
            self.lr=self.critic_lr
            #print(self.lr)
            self.loss_func.generator_mode = False
            self._with_events(self._do_critic_epoch, 'epoch', CancelEpochException)
            self._with_events(self._do_noise_critic_epoch, 'epoch', CancelEpochException)
    else:
        for epoch in range(self.n_epoch):
            self.epoch=epoch
            #Critic Training
            self.opt.set_hypers(lr=self.critic_lr)
            self.lr=self.critic_lr
            #print(self.lr)
            self.loss_func.generator_mode = False
            self._with_events(self._do_critic_epoch, 'epoch', CancelEpochException)
            self._with_events(self._do_noise_critic_epoch, 'epoch', CancelEpochException)
            
            self.opt.set_hypers(lr=self.generator_lr)
            self.lr=self.generator_lr
            #print(self.lr)
            self.loss_func.generator_mode = True
            self._with_events(self._do_generator_epoch, 'epoch', CancelEpochException)

def GANfit(self, n_epoch, critic_lr=1e-6, generator_lr = 1e-3, wd=None, cbs=None, reset_opt=False):
    with self.added_cbs(cbs):
        if reset_opt or not self.opt: self.create_opt()
        if wd is None: wd = self.wd
        if wd is not None: self.opt.set_hypers(wd=wd)
        self.critic_lr = critic_lr
        self.generator_lr = generator_lr
        #self.opt.set_hypers(lr=self.lr if lr is None else lr)
        self.n_epoch = n_epoch
        self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
        
Learner._do_fit = _GAN_do_fit
Learner._do_generator_epoch = _do_generator_epoch
Learner._do_critic_epoch = _do_critic_epoch
Learner._do_noise_critic_epoch = _do_noise_critic_epoch
Learner.fit = GANfit

# %%
learner = Learner(dloader, gan, loss_func=GanLoss, splitter=trainable_params, 
                  metrics=[Accuracy])

# %%
#Critic Loss: TensorCategory(39.4336, device='cuda:0', grad_fn=<AliasBackward>)
learner.lr_find()
# Out:
# SuggestedLRs(lr_min=3.6307807022240014e-06, lr_steep=9.12010818865383e-07)

# %%
learner.model.generatorSwitcher()
learner.model.noiseSwitcher()
learner.model.paramsToUpdate()
print("Noise mode:", learner.model.noise_mode)
print("Generator mode:", learner.model.generator_mode)
learner.model.assertParams()
learner.lr_find(start_lr=1e-7, end_lr=1)
# Out:
# Noise mode: True
# Generator mode: True
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# Generator Loss
# Reconstruction Loss: TensorImage(0., device='cuda:0', grad_fn=<AliasBackward>)
# SuggestedLRs(lr_min=5.011872303839482e-08, lr_steep=5.011872303839482e-07)

# %%
learner.fit(2, critic_lr=1-7, generator_lr = 1e-7)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1' class='' max='2' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       50.00% [1/2 01:36<01:36]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>Adversarial_loss</th>
#       <th>Reconstruction_Loss</th>
#       <th>Accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.194794</td>
#       <td>0.272864</td>
#       <td>-2.530135</td>
#       <td>0.285514</td>
#       <td>0.240000</td>
#       <td>00:43</td>
#     </tr>
#     <tr>
#       <td>0</td>
#       <td>677136596274266807205888.000000</td>
#       <td>3628933133827126176251904.000000</td>
#       <td>-3628933133827126176251904.000000</td>
#       <td>0.000000</td>
#       <td>0.240000</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>0</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.327174</td>
#       <td>0.310000</td>
#       <td>00:31</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.310000</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>nan</td>
#       <td>0.000000</td>
#       <td>0.310000</td>
#       <td>00:22</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='44' class='' max='160' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       27.50% [44/160 00:08<00:21 nan]
#     </div>
# Parameter containing:
# tensor([ -14.4485,   47.9607,  149.1628,  -48.5427,    7.0355,   10.7307,
#          -19.0139,    1.1982,   11.8594,   81.6843,   -2.8117,    0.3938,
#            4.9066,  102.1968, -127.5427, -103.3052, -137.2662, -116.7131,
#           23.0194,  -18.5555,  -25.5104,    0.6239,   60.4850,  -17.7095,
#           -1.4675,   35.9805,   -6.5466,  -84.2875,  330.8603,   21.8212,
#         -320.7956,    2.7322,   16.7312,  185.3829,    0.6307,   80.7426,
#          -66.5774,  -10.2700,  -79.2629,   33.2380,  -61.3685,    1.5536,
#         -155.1859,  -24.5799,    4.3337,  -11.4993,   17.6527,   -3.7159,
#         -108.8370,  -33.8976,  -69.3589,   24.2964,   45.2684,   11.8844,
#           23.4500,   -3.9870,  113.9699,  116.5188,  -18.9923,   -0.7707,
#          -80.2739,    6.6324,  -17.3737,  -46.2980], device='cuda:0',
#        requires_grad=True) True
# Parameter containing:
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#        device='cuda:0', requires_grad=True) True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-7fa1d193f7f5> in <module>
# ----> 1 learner.fit(2, critic_lr=1-7, generator_lr = 1e-7)
#
# <ipython-input-8-27cd2e4b3b20> in GANfit(self, n_epoch, critic_lr, generator_lr, wd, cbs, reset_opt)
#     116         #self.opt.set_hypers(lr=self.lr if lr is None else lr)
#     117         self.n_epoch = n_epoch
# --> 118         self._with_events(self._do_fit, 'fit', CancelFitException, self._end_cleanup)
#     119
#     120 Learner._do_fit = _GAN_do_fit
#
# ~/anaconda3/envs/Luiz2/lib/python3.8/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     158
#     159     def _with_events(self, f, event_type, ex, final=noop):
# --> 160         try: self(f'before_{event_type}');  f()
#     161         except ex: self(f'after_cancel_{event_type}')
#     162         self(f'after_{event_type}');  final()
#
# <ipython-input-8-27cd2e4b3b20> in _GAN_do_fit(self)
#      89             self.loss_func.generator_mode = False
#      90             self._with_events(self._do_critic_epoch, 'epoch', CancelEpochException)
# ---> 91             self._with_events(self._do_noise_critic_epoch, 'epoch', CancelEpochException)
#      92     else:
#      93         for epoch in range(self.n_epoch):
#
# ~/anaconda3/envs/Luiz2/lib/python3.8/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     158
#     159     def _with_events(self, f, event_type, ex, final=noop):
# --> 160         try: self(f'before_{event_type}');  f()
#     161         except ex: self(f'after_cancel_{event_type}')
#     162         self(f'after_{event_type}');  final()
#
# <ipython-input-8-27cd2e4b3b20> in _do_noise_critic_epoch(self)
#      45             print(p, p.requires_grad)
#      46
# ---> 47     self._do_epoch_train()
#      48     self._do_epoch_validate()
#      49
#
# ~/anaconda3/envs/Luiz2/lib/python3.8/site-packages/fastai/learner.py in _do_epoch_train(self)
#     186     def _do_epoch_train(self):
#     187         self.dl = self.dls.train
# --> 188         self._with_events(self.all_batches, 'train', CancelTrainException)
#     189
#     190     def _do_epoch_validate(self, ds_idx=1, dl=None):
#
# ~/anaconda3/envs/Luiz2/lib/python3.8/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     158
#     159     def _with_events(self, f, event_type, ex, final=noop):
# --> 160         try: self(f'before_{event_type}');  f()
#     161         except ex: self(f'after_cancel_{event_type}')
#     162         self(f'after_{event_type}');  final()
#
# ~/anaconda3/envs/Luiz2/lib/python3.8/site-packages/fastai/learner.py in all_batches(self)
#     164     def all_batches(self):
#     165         self.n_iter = len(self.dl)
# --> 166         for o in enumerate(self.dl): self.one_batch(*o)
#     167
#     168     def _do_one_batch(self):
#
# ~/anaconda3/envs/Luiz2/lib/python3.8/site-packages/fastai/learner.py in one_batch(self, i, b)
#     182         self.iter = i
#     183         self._split(b)
# --> 184         self._with_events(self._do_one_batch, 'batch', CancelBatchException)
#     185
#     186     def _do_epoch_train(self):
#
# ~/anaconda3/envs/Luiz2/lib/python3.8/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     158
#     159     def _with_events(self, f, event_type, ex, final=noop):
# --> 160         try: self(f'before_{event_type}');  f()
#     161         except ex: self(f'after_cancel_{event_type}')
#     162         self(f'after_{event_type}');  final()
#
# ~/anaconda3/envs/Luiz2/lib/python3.8/site-packages/fastai/learner.py in _do_one_batch(self)
#     176         self('before_backward')
#     177         self.loss_grad.backward()
# --> 178         self._with_events(self.opt.step, 'step', CancelStepException)
#     179         self.opt.zero_grad()
#     180
#
# ~/anaconda3/envs/Luiz2/lib/python3.8/site-packages/fastai/learner.py in _with_events(self, f, event_type, ex, final)
#     158
#     159     def _with_events(self, f, event_type, ex, final=noop):
# --> 160         try: self(f'before_{event_type}');  f()
#     161         except ex: self(f'after_cancel_{event_type}')
#     162         self(f'after_{event_type}');  final()
#
# ~/anaconda3/envs/Luiz2/lib/python3.8/site-packages/fastai/optimizer.py in step(self)
#      80     def step(self):
#      81         for p,pg,state,hyper in self.all_params(with_grad=True):
# ---> 82             for cb in self.cbs: state = _update(state, cb(p, **{**state, **hyper}))
#      83             self.state[p] = state
#      84
#
# ~/anaconda3/envs/Luiz2/lib/python3.8/site-packages/fastai/optimizer.py in adam_step(p, lr, mom, step, sqr_mom, grad_avg, sqr_avg, eps, **kwargs)
#     177     debias1 = debias(mom,     1-mom,     step)
#     178     debias2 = debias(sqr_mom, 1-sqr_mom, step)
# --> 179     p.data.addcdiv_(grad_avg, (sqr_avg/debias2).sqrt() + eps, value = -lr / debias1)
#     180     return p
#     181
#
# KeyboardInterrupt:

# %%
for name, param in learner.model.generator.named_parameters():
    #param.requires_grad = False
    print(name, param.requires_grad)
# Out:
# inc.double_conv.0.weight False
# inc.double_conv.0.bias False
# inc.double_conv.1.weight False
# inc.double_conv.1.bias False
# inc.double_conv.3.weight False
# inc.double_conv.3.bias False
# inc.double_conv.4.weight False
# inc.double_conv.4.bias False
# down1.maxpool_conv.1.double_conv.0.weight False
# down1.maxpool_conv.1.double_conv.0.bias False
# down1.maxpool_conv.1.double_conv.1.weight False
# down1.maxpool_conv.1.double_conv.1.bias False
# down1.maxpool_conv.1.double_conv.3.weight False
# down1.maxpool_conv.1.double_conv.3.bias False
# down1.maxpool_conv.1.double_conv.4.weight False
# down1.maxpool_conv.1.double_conv.4.bias False
# down2.maxpool_conv.1.double_conv.0.weight False
# down2.maxpool_conv.1.double_conv.0.bias False
# down2.maxpool_conv.1.double_conv.1.weight False
# down2.maxpool_conv.1.double_conv.1.bias False
# down2.maxpool_conv.1.double_conv.3.weight False
# down2.maxpool_conv.1.double_conv.3.bias False
# down2.maxpool_conv.1.double_conv.4.weight False
# down2.maxpool_conv.1.double_conv.4.bias False
# down3.maxpool_conv.1.double_conv.0.weight False
# down3.maxpool_conv.1.double_conv.0.bias False
# down3.maxpool_conv.1.double_conv.1.weight False
# down3.maxpool_conv.1.double_conv.1.bias False
# down3.maxpool_conv.1.double_conv.3.weight False
# down3.maxpool_conv.1.double_conv.3.bias False
# down3.maxpool_conv.1.double_conv.4.weight False
# down3.maxpool_conv.1.double_conv.4.bias False
# up2.up.weight False
# up2.up.bias False
# up2.conv.double_conv.0.weight False
# up2.conv.double_conv.0.bias False
# up2.conv.double_conv.1.weight False
# up2.conv.double_conv.1.bias False
# up2.conv.double_conv.3.weight False
# up2.conv.double_conv.3.bias False
# up2.conv.double_conv.4.weight False
# up2.conv.double_conv.4.bias False
# up3.up.weight False
# up3.up.bias False
# up3.conv.double_conv.0.weight False
# up3.conv.double_conv.0.bias False
# up3.conv.double_conv.1.weight False
# up3.conv.double_conv.1.bias False
# up3.conv.double_conv.3.weight False
# up3.conv.double_conv.3.bias False
# up3.conv.double_conv.4.weight False
# up3.conv.double_conv.4.bias False
# up4.up.weight False
# up4.up.bias False
# up4.conv.double_conv.0.weight False
# up4.conv.double_conv.0.bias False
# up4.conv.double_conv.1.weight False
# up4.conv.double_conv.1.bias False
# up4.conv.double_conv.3.weight False
# up4.conv.double_conv.3.bias False
# up4.conv.double_conv.4.weight False
# up4.conv.double_conv.4.bias False
# outc.conv.weight False
# outc.conv.bias False

# %%
for name, param in learner.model.named_parameters():
    fb = ["mask","penalty_mask","pos"]
    #if name not in fb:
    #    param.requires_grad = True
    #else:
    #    param.requires_grad = False
    print(name, param.requires_grad)
# Out:
# generator.inc.double_conv.0.weight True
# generator.inc.double_conv.0.bias True
# generator.inc.double_conv.1.weight True
# generator.inc.double_conv.1.bias True
# generator.inc.double_conv.3.weight True
# generator.inc.double_conv.3.bias True
# generator.inc.double_conv.4.weight True
# generator.inc.double_conv.4.bias True
# generator.down1.maxpool_conv.1.double_conv.0.weight True
# generator.down1.maxpool_conv.1.double_conv.0.bias True
# generator.down1.maxpool_conv.1.double_conv.1.weight True
# generator.down1.maxpool_conv.1.double_conv.1.bias True
# generator.down1.maxpool_conv.1.double_conv.3.weight True
# generator.down1.maxpool_conv.1.double_conv.3.bias True
# generator.down1.maxpool_conv.1.double_conv.4.weight True
# generator.down1.maxpool_conv.1.double_conv.4.bias True
# generator.down2.maxpool_conv.1.double_conv.0.weight True
# generator.down2.maxpool_conv.1.double_conv.0.bias True
# generator.down2.maxpool_conv.1.double_conv.1.weight True
# generator.down2.maxpool_conv.1.double_conv.1.bias True
# generator.down2.maxpool_conv.1.double_conv.3.weight True
# generator.down2.maxpool_conv.1.double_conv.3.bias True
# generator.down2.maxpool_conv.1.double_conv.4.weight True
# generator.down2.maxpool_conv.1.double_conv.4.bias True
# generator.down3.maxpool_conv.1.double_conv.0.weight True
# generator.down3.maxpool_conv.1.double_conv.0.bias True
# generator.down3.maxpool_conv.1.double_conv.1.weight True
# generator.down3.maxpool_conv.1.double_conv.1.bias True
# generator.down3.maxpool_conv.1.double_conv.3.weight True
# generator.down3.maxpool_conv.1.double_conv.3.bias True
# generator.down3.maxpool_conv.1.double_conv.4.weight True
# generator.down3.maxpool_conv.1.double_conv.4.bias True
# generator.up2.up.weight True
# generator.up2.up.bias True
# generator.up2.conv.double_conv.0.weight True
# generator.up2.conv.double_conv.0.bias True
# generator.up2.conv.double_conv.1.weight True
# generator.up2.conv.double_conv.1.bias True
# generator.up2.conv.double_conv.3.weight True
# generator.up2.conv.double_conv.3.bias True
# generator.up2.conv.double_conv.4.weight True
# generator.up2.conv.double_conv.4.bias True
# generator.up3.up.weight True
# generator.up3.up.bias True
# generator.up3.conv.double_conv.0.weight True
# generator.up3.conv.double_conv.0.bias True
# generator.up3.conv.double_conv.1.weight True
# generator.up3.conv.double_conv.1.bias True
# generator.up3.conv.double_conv.3.weight True
# generator.up3.conv.double_conv.3.bias True
# generator.up3.conv.double_conv.4.weight True
# generator.up3.conv.double_conv.4.bias True
# generator.up4.up.weight True
# generator.up4.up.bias True
# generator.up4.conv.double_conv.0.weight True
# generator.up4.conv.double_conv.0.bias True
# generator.up4.conv.double_conv.1.weight True
# generator.up4.conv.double_conv.1.bias True
# generator.up4.conv.double_conv.3.weight True
# generator.up4.conv.double_conv.3.bias True
# generator.up4.conv.double_conv.4.weight True
# generator.up4.conv.double_conv.4.bias True
# generator.outc.conv.weight True
# generator.outc.conv.bias True
# model.pos False
# model.mask False
# model.penalty_mask False
# model.backbone.backbone.conv1.weight False
# model.backbone.backbone.bn1.weight False
# model.backbone.backbone.bn1.bias False
# model.backbone.backbone.layer1.0.conv1.weight False
# model.backbone.backbone.layer1.0.bn1.weight False
# model.backbone.backbone.layer1.0.bn1.bias False
# model.backbone.backbone.layer1.0.conv2.weight False
# model.backbone.backbone.layer1.0.bn2.weight False
# model.backbone.backbone.layer1.0.bn2.bias False
# model.backbone.backbone.layer1.0.conv3.weight False
# model.backbone.backbone.layer1.0.bn3.weight False
# model.backbone.backbone.layer1.0.bn3.bias False
# model.backbone.backbone.layer1.0.downsample.0.weight False
# model.backbone.backbone.layer1.0.downsample.1.weight False
# model.backbone.backbone.layer1.0.downsample.1.bias False
# model.backbone.backbone.layer1.1.conv1.weight False
# model.backbone.backbone.layer1.1.bn1.weight False
# model.backbone.backbone.layer1.1.bn1.bias False
# model.backbone.backbone.layer1.1.conv2.weight False
# model.backbone.backbone.layer1.1.bn2.weight False
# model.backbone.backbone.layer1.1.bn2.bias False
# model.backbone.backbone.layer1.1.conv3.weight False
# model.backbone.backbone.layer1.1.bn3.weight False
# model.backbone.backbone.layer1.1.bn3.bias False
# model.backbone.backbone.layer1.2.conv1.weight False
# model.backbone.backbone.layer1.2.bn1.weight False
# model.backbone.backbone.layer1.2.bn1.bias False
# model.backbone.backbone.layer1.2.conv2.weight False
# model.backbone.backbone.layer1.2.bn2.weight False
# model.backbone.backbone.layer1.2.bn2.bias False
# model.backbone.backbone.layer1.2.conv3.weight False
# model.backbone.backbone.layer1.2.bn3.weight False
# model.backbone.backbone.layer1.2.bn3.bias False
# model.backbone.backbone.layer2.0.conv1.weight False
# model.backbone.backbone.layer2.0.bn1.weight False
# model.backbone.backbone.layer2.0.bn1.bias False
# model.backbone.backbone.layer2.0.conv2.weight False
# model.backbone.backbone.layer2.0.bn2.weight False
# model.backbone.backbone.layer2.0.bn2.bias False
# model.backbone.backbone.layer2.0.conv3.weight False
# model.backbone.backbone.layer2.0.bn3.weight False
# model.backbone.backbone.layer2.0.bn3.bias False
# model.backbone.backbone.layer2.0.downsample.0.weight False
# model.backbone.backbone.layer2.0.downsample.1.weight False
# model.backbone.backbone.layer2.0.downsample.1.bias False
# model.backbone.backbone.layer2.1.conv1.weight False
# model.backbone.backbone.layer2.1.bn1.weight False
# model.backbone.backbone.layer2.1.bn1.bias False
# model.backbone.backbone.layer2.1.conv2.weight False
# model.backbone.backbone.layer2.1.bn2.weight False
# model.backbone.backbone.layer2.1.bn2.bias False
# model.backbone.backbone.layer2.1.conv3.weight False
# model.backbone.backbone.layer2.1.bn3.weight False
# model.backbone.backbone.layer2.1.bn3.bias False
# model.backbone.backbone.layer2.2.conv1.weight False
# model.backbone.backbone.layer2.2.bn1.weight False
# model.backbone.backbone.layer2.2.bn1.bias False
# model.backbone.backbone.layer2.2.conv2.weight False
# model.backbone.backbone.layer2.2.bn2.weight False
# model.backbone.backbone.layer2.2.bn2.bias False
# model.backbone.backbone.layer2.2.conv3.weight False
# model.backbone.backbone.layer2.2.bn3.weight False
# model.backbone.backbone.layer2.2.bn3.bias False
# model.backbone.backbone.layer2.3.conv1.weight False
# model.backbone.backbone.layer2.3.bn1.weight False
# model.backbone.backbone.layer2.3.bn1.bias False
# model.backbone.backbone.layer2.3.conv2.weight False
# model.backbone.backbone.layer2.3.bn2.weight False
# model.backbone.backbone.layer2.3.bn2.bias False
# model.backbone.backbone.layer2.3.conv3.weight False
# model.backbone.backbone.layer2.3.bn3.weight False
# model.backbone.backbone.layer2.3.bn3.bias False
# model.backbone.backbone.layer3.0.conv1.weight False
# model.backbone.backbone.layer3.0.bn1.weight False
# model.backbone.backbone.layer3.0.bn1.bias False
# model.backbone.backbone.layer3.0.conv2.weight False
# model.backbone.backbone.layer3.0.bn2.weight False
# model.backbone.backbone.layer3.0.bn2.bias False
# model.backbone.backbone.layer3.0.conv3.weight False
# model.backbone.backbone.layer3.0.bn3.weight False
# model.backbone.backbone.layer3.0.bn3.bias False
# model.backbone.backbone.layer3.0.downsample.0.weight False
# model.backbone.backbone.layer3.0.downsample.1.weight False
# model.backbone.backbone.layer3.0.downsample.1.bias False
# model.backbone.backbone.layer3.1.conv1.weight False
# model.backbone.backbone.layer3.1.bn1.weight False
# model.backbone.backbone.layer3.1.bn1.bias False
# model.backbone.backbone.layer3.1.conv2.weight False
# model.backbone.backbone.layer3.1.bn2.weight False
# model.backbone.backbone.layer3.1.bn2.bias False
# model.backbone.backbone.layer3.1.conv3.weight False
# model.backbone.backbone.layer3.1.bn3.weight False
# model.backbone.backbone.layer3.1.bn3.bias False
# model.backbone.backbone.layer3.2.conv1.weight False
# model.backbone.backbone.layer3.2.bn1.weight False
# model.backbone.backbone.layer3.2.bn1.bias False
# model.backbone.backbone.layer3.2.conv2.weight False
# model.backbone.backbone.layer3.2.bn2.weight False
# model.backbone.backbone.layer3.2.bn2.bias False
# model.backbone.backbone.layer3.2.conv3.weight False
# model.backbone.backbone.layer3.2.bn3.weight False
# model.backbone.backbone.layer3.2.bn3.bias False
# model.backbone.backbone.layer3.3.conv1.weight False
# model.backbone.backbone.layer3.3.bn1.weight False
# model.backbone.backbone.layer3.3.bn1.bias False
# model.backbone.backbone.layer3.3.conv2.weight False
# model.backbone.backbone.layer3.3.bn2.weight False
# model.backbone.backbone.layer3.3.bn2.bias False
# model.backbone.backbone.layer3.3.conv3.weight False
# model.backbone.backbone.layer3.3.bn3.weight False
# model.backbone.backbone.layer3.3.bn3.bias False
# model.backbone.backbone.layer3.4.conv1.weight False
# model.backbone.backbone.layer3.4.bn1.weight False
# model.backbone.backbone.layer3.4.bn1.bias False
# model.backbone.backbone.layer3.4.conv2.weight False
# model.backbone.backbone.layer3.4.bn2.weight False
# model.backbone.backbone.layer3.4.bn2.bias False
# model.backbone.backbone.layer3.4.conv3.weight False
# model.backbone.backbone.layer3.4.bn3.weight False
# model.backbone.backbone.layer3.4.bn3.bias False
# model.backbone.backbone.layer3.5.conv1.weight False
# model.backbone.backbone.layer3.5.bn1.weight False
# model.backbone.backbone.layer3.5.bn1.bias False
# model.backbone.backbone.layer3.5.conv2.weight False
# model.backbone.backbone.layer3.5.bn2.weight False
# model.backbone.backbone.layer3.5.bn2.bias False
# model.backbone.backbone.layer3.5.conv3.weight False
# model.backbone.backbone.layer3.5.bn3.weight False
# model.backbone.backbone.layer3.5.bn3.bias False
# model.backbone.backbone.layer3.6.conv1.weight False
# model.backbone.backbone.layer3.6.bn1.weight False
# model.backbone.backbone.layer3.6.bn1.bias False
# model.backbone.backbone.layer3.6.conv2.weight False
# model.backbone.backbone.layer3.6.bn2.weight False
# model.backbone.backbone.layer3.6.bn2.bias False
# model.backbone.backbone.layer3.6.conv3.weight False
# model.backbone.backbone.layer3.6.bn3.weight False
# model.backbone.backbone.layer3.6.bn3.bias False
# model.backbone.backbone.layer3.7.conv1.weight False
# model.backbone.backbone.layer3.7.bn1.weight False
# model.backbone.backbone.layer3.7.bn1.bias False
# model.backbone.backbone.layer3.7.conv2.weight False
# model.backbone.backbone.layer3.7.bn2.weight False
# model.backbone.backbone.layer3.7.bn2.bias False
# model.backbone.backbone.layer3.7.conv3.weight False
# model.backbone.backbone.layer3.7.bn3.weight False
# model.backbone.backbone.layer3.7.bn3.bias False
# model.backbone.backbone.layer3.8.conv1.weight False
# model.backbone.backbone.layer3.8.bn1.weight False
# model.backbone.backbone.layer3.8.bn1.bias False
# model.backbone.backbone.layer3.8.conv2.weight False
# model.backbone.backbone.layer3.8.bn2.weight False
# model.backbone.backbone.layer3.8.bn2.bias False
# model.backbone.backbone.layer3.8.conv3.weight False
# model.backbone.backbone.layer3.8.bn3.weight False
# model.backbone.backbone.layer3.8.bn3.bias False
# model.backbone.backbone.layer3.9.conv1.weight False
# model.backbone.backbone.layer3.9.bn1.weight False
# model.backbone.backbone.layer3.9.bn1.bias False
# model.backbone.backbone.layer3.9.conv2.weight False
# model.backbone.backbone.layer3.9.bn2.weight False
# model.backbone.backbone.layer3.9.bn2.bias False
# model.backbone.backbone.layer3.9.conv3.weight False
# model.backbone.backbone.layer3.9.bn3.weight False
# model.backbone.backbone.layer3.9.bn3.bias False
# model.backbone.backbone.layer3.10.conv1.weight False
# model.backbone.backbone.layer3.10.bn1.weight False
# model.backbone.backbone.layer3.10.bn1.bias False
# model.backbone.backbone.layer3.10.conv2.weight False
# model.backbone.backbone.layer3.10.bn2.weight False
# model.backbone.backbone.layer3.10.bn2.bias False
# model.backbone.backbone.layer3.10.conv3.weight False
# model.backbone.backbone.layer3.10.bn3.weight False
# model.backbone.backbone.layer3.10.bn3.bias False
# model.backbone.backbone.layer3.11.conv1.weight False
# model.backbone.backbone.layer3.11.bn1.weight False
# model.backbone.backbone.layer3.11.bn1.bias False
# model.backbone.backbone.layer3.11.conv2.weight False
# model.backbone.backbone.layer3.11.bn2.weight False
# model.backbone.backbone.layer3.11.bn2.bias False
# model.backbone.backbone.layer3.11.conv3.weight False
# model.backbone.backbone.layer3.11.bn3.weight False
# model.backbone.backbone.layer3.11.bn3.bias False
# model.backbone.backbone.layer3.12.conv1.weight False
# model.backbone.backbone.layer3.12.bn1.weight False
# model.backbone.backbone.layer3.12.bn1.bias False
# model.backbone.backbone.layer3.12.conv2.weight False
# model.backbone.backbone.layer3.12.bn2.weight False
# model.backbone.backbone.layer3.12.bn2.bias False
# model.backbone.backbone.layer3.12.conv3.weight False
# model.backbone.backbone.layer3.12.bn3.weight False
# model.backbone.backbone.layer3.12.bn3.bias False
# model.backbone.backbone.layer3.13.conv1.weight False
# model.backbone.backbone.layer3.13.bn1.weight False
# model.backbone.backbone.layer3.13.bn1.bias False
# model.backbone.backbone.layer3.13.conv2.weight False
# model.backbone.backbone.layer3.13.bn2.weight False
# model.backbone.backbone.layer3.13.bn2.bias False
# model.backbone.backbone.layer3.13.conv3.weight False
# model.backbone.backbone.layer3.13.bn3.weight False
# model.backbone.backbone.layer3.13.bn3.bias False
# model.backbone.backbone.layer3.14.conv1.weight False
# model.backbone.backbone.layer3.14.bn1.weight False
# model.backbone.backbone.layer3.14.bn1.bias False
# model.backbone.backbone.layer3.14.conv2.weight False
# model.backbone.backbone.layer3.14.bn2.weight False
# model.backbone.backbone.layer3.14.bn2.bias False
# model.backbone.backbone.layer3.14.conv3.weight False
# model.backbone.backbone.layer3.14.bn3.weight False
# model.backbone.backbone.layer3.14.bn3.bias False
# model.backbone.backbone.layer3.15.conv1.weight False
# model.backbone.backbone.layer3.15.bn1.weight False
# model.backbone.backbone.layer3.15.bn1.bias False
# model.backbone.backbone.layer3.15.conv2.weight False
# model.backbone.backbone.layer3.15.bn2.weight False
# model.backbone.backbone.layer3.15.bn2.bias False
# model.backbone.backbone.layer3.15.conv3.weight False
# model.backbone.backbone.layer3.15.bn3.weight False
# model.backbone.backbone.layer3.15.bn3.bias False
# model.backbone.backbone.layer3.16.conv1.weight False
# model.backbone.backbone.layer3.16.bn1.weight False
# model.backbone.backbone.layer3.16.bn1.bias False
# model.backbone.backbone.layer3.16.conv2.weight False
# model.backbone.backbone.layer3.16.bn2.weight False
# model.backbone.backbone.layer3.16.bn2.bias False
# model.backbone.backbone.layer3.16.conv3.weight False
# model.backbone.backbone.layer3.16.bn3.weight False
# model.backbone.backbone.layer3.16.bn3.bias False
# model.backbone.backbone.layer3.17.conv1.weight False
# model.backbone.backbone.layer3.17.bn1.weight False
# model.backbone.backbone.layer3.17.bn1.bias False
# model.backbone.backbone.layer3.17.conv2.weight False
# model.backbone.backbone.layer3.17.bn2.weight False
# model.backbone.backbone.layer3.17.bn2.bias False
# model.backbone.backbone.layer3.17.conv3.weight False
# model.backbone.backbone.layer3.17.bn3.weight False
# model.backbone.backbone.layer3.17.bn3.bias False
# model.backbone.backbone.layer3.18.conv1.weight False
# model.backbone.backbone.layer3.18.bn1.weight False
# model.backbone.backbone.layer3.18.bn1.bias False
# model.backbone.backbone.layer3.18.conv2.weight False
# model.backbone.backbone.layer3.18.bn2.weight False
# model.backbone.backbone.layer3.18.bn2.bias False
# model.backbone.backbone.layer3.18.conv3.weight False
# model.backbone.backbone.layer3.18.bn3.weight False
# model.backbone.backbone.layer3.18.bn3.bias False
# model.backbone.backbone.layer3.19.conv1.weight False
# model.backbone.backbone.layer3.19.bn1.weight False
# model.backbone.backbone.layer3.19.bn1.bias False
# model.backbone.backbone.layer3.19.conv2.weight False
# model.backbone.backbone.layer3.19.bn2.weight False
# model.backbone.backbone.layer3.19.bn2.bias False
# model.backbone.backbone.layer3.19.conv3.weight False
# model.backbone.backbone.layer3.19.bn3.weight False
# model.backbone.backbone.layer3.19.bn3.bias False
# model.backbone.backbone.layer3.20.conv1.weight False
# model.backbone.backbone.layer3.20.bn1.weight False
# model.backbone.backbone.layer3.20.bn1.bias False
# model.backbone.backbone.layer3.20.conv2.weight False
# model.backbone.backbone.layer3.20.bn2.weight False
# model.backbone.backbone.layer3.20.bn2.bias False
# model.backbone.backbone.layer3.20.conv3.weight False
# model.backbone.backbone.layer3.20.bn3.weight False
# model.backbone.backbone.layer3.20.bn3.bias False
# model.backbone.backbone.layer3.21.conv1.weight False
# model.backbone.backbone.layer3.21.bn1.weight False
# model.backbone.backbone.layer3.21.bn1.bias False
# model.backbone.backbone.layer3.21.conv2.weight False
# model.backbone.backbone.layer3.21.bn2.weight False
# model.backbone.backbone.layer3.21.bn2.bias False
# model.backbone.backbone.layer3.21.conv3.weight False
# model.backbone.backbone.layer3.21.bn3.weight False
# model.backbone.backbone.layer3.21.bn3.bias False
# model.backbone.backbone.layer3.22.conv1.weight False
# model.backbone.backbone.layer3.22.bn1.weight False
# model.backbone.backbone.layer3.22.bn1.bias False
# model.backbone.backbone.layer3.22.conv2.weight False
# model.backbone.backbone.layer3.22.bn2.weight False
# model.backbone.backbone.layer3.22.bn2.bias False
# model.backbone.backbone.layer3.22.conv3.weight False
# model.backbone.backbone.layer3.22.bn3.weight False
# model.backbone.backbone.layer3.22.bn3.bias False
# model.backbone.conv.weight False
# model.backbone.conv.bias False
# model.encoder.encoder.layers.0.self_attn.in_proj_weight False
# model.encoder.encoder.layers.0.self_attn.in_proj_bias False
# model.encoder.encoder.layers.0.self_attn.out_proj.weight False
# model.encoder.encoder.layers.0.self_attn.out_proj.bias False
# model.encoder.encoder.layers.0.linear1.weight False
# model.encoder.encoder.layers.0.linear1.bias False
# model.encoder.encoder.layers.0.linear2.weight False
# model.encoder.encoder.layers.0.linear2.bias False
# model.encoder.encoder.layers.0.norm1.weight False
# model.encoder.encoder.layers.0.norm1.bias False
# model.encoder.encoder.layers.0.norm2.weight False
# model.encoder.encoder.layers.0.norm2.bias False
# model.encoder.encoder.layers.1.self_attn.in_proj_weight False
# model.encoder.encoder.layers.1.self_attn.in_proj_bias False
# model.encoder.encoder.layers.1.self_attn.out_proj.weight False
# model.encoder.encoder.layers.1.self_attn.out_proj.bias False
# model.encoder.encoder.layers.1.linear1.weight False
# model.encoder.encoder.layers.1.linear1.bias False
# model.encoder.encoder.layers.1.linear2.weight False
# model.encoder.encoder.layers.1.linear2.bias False
# model.encoder.encoder.layers.1.norm1.weight False
# model.encoder.encoder.layers.1.norm1.bias False
# model.encoder.encoder.layers.1.norm2.weight False
# model.encoder.encoder.layers.1.norm2.bias False
# model.encoder.encoder.layers.2.self_attn.in_proj_weight False
# model.encoder.encoder.layers.2.self_attn.in_proj_bias False
# model.encoder.encoder.layers.2.self_attn.out_proj.weight False
# model.encoder.encoder.layers.2.self_attn.out_proj.bias False
# model.encoder.encoder.layers.2.linear1.weight False
# model.encoder.encoder.layers.2.linear1.bias False
# model.encoder.encoder.layers.2.linear2.weight False
# model.encoder.encoder.layers.2.linear2.bias False
# model.encoder.encoder.layers.2.norm1.weight False
# model.encoder.encoder.layers.2.norm1.bias False
# model.encoder.encoder.layers.2.norm2.weight False
# model.encoder.encoder.layers.2.norm2.bias False
# model.encoder.encoder.layers.3.self_attn.in_proj_weight False
# model.encoder.encoder.layers.3.self_attn.in_proj_bias False
# model.encoder.encoder.layers.3.self_attn.out_proj.weight False
# model.encoder.encoder.layers.3.self_attn.out_proj.bias False
# model.encoder.encoder.layers.3.linear1.weight False
# model.encoder.encoder.layers.3.linear1.bias False
# model.encoder.encoder.layers.3.linear2.weight False
# model.encoder.encoder.layers.3.linear2.bias False
# model.encoder.encoder.layers.3.norm1.weight False
# model.encoder.encoder.layers.3.norm1.bias False
# model.encoder.encoder.layers.3.norm2.weight False
# model.encoder.encoder.layers.3.norm2.bias False
# model.fc1.weight False
# model.fc1.bias False

# %%
gan.generator_mode = False
def trainable_params(m):
    "Return all trainable parameters of `m`"
    if m.generator_mode == True:
        m.noise_mode = True
        for param in m.generator.parameters():
            param.requires_grad = True
        for param in m.model.parameters():
            param.requires_grad = False
    else:
        for param in m.generator.parameters():
            param.requires_grad = False
        for name, param in m.model.named_parameters():
            fb = ["mask","penalty_mask","pos"]
            if name not in fb:
                param.requires_grad = True
            else:
                param.requires_grad = False
    return [p for p in m.parameters() if p.requires_grad]
# Out:
# ['model.backbone.weight',
#  'model.backbone.bias',
#  'model.encoder.encoder.layers.0.self_attn.in_proj_weight',
#  'model.encoder.encoder.layers.0.self_attn.in_proj_bias',
#  'model.encoder.encoder.layers.0.self_attn.out_proj.weight',
#  'model.encoder.encoder.layers.0.self_attn.out_proj.bias',
#  'model.encoder.encoder.layers.0.linear1.weight',
#  'model.encoder.encoder.layers.0.linear1.bias',
#  'model.encoder.encoder.layers.0.linear2.weight',
#  'model.encoder.encoder.layers.0.linear2.bias',
#  'model.encoder.encoder.layers.0.norm1.weight',
#  'model.encoder.encoder.layers.0.norm1.bias',
#  'model.encoder.encoder.layers.0.norm2.weight',
#  'model.encoder.encoder.layers.0.norm2.bias',
#  'model.encoder.encoder.layers.1.self_attn.in_proj_weight',
#  'model.encoder.encoder.layers.1.self_attn.in_proj_bias',
#  'model.encoder.encoder.layers.1.self_attn.out_proj.weight',
#  'model.encoder.encoder.layers.1.self_attn.out_proj.bias',
#  'model.encoder.encoder.layers.1.linear1.weight',
#  'model.encoder.encoder.layers.1.linear1.bias',
#  'model.encoder.encoder.layers.1.linear2.weight',
#  'model.encoder.encoder.layers.1.linear2.bias',
#  'model.encoder.encoder.layers.1.norm1.weight',
#  'model.encoder.encoder.layers.1.norm1.bias',
#  'model.encoder.encoder.layers.1.norm2.weight',
#  'model.encoder.encoder.layers.1.norm2.bias',
#  'model.encoder.encoder.layers.2.self_attn.in_proj_weight',
#  'model.encoder.encoder.layers.2.self_attn.in_proj_bias',
#  'model.encoder.encoder.layers.2.self_attn.out_proj.weight',
#  'model.encoder.encoder.layers.2.self_attn.out_proj.bias',
#  'model.encoder.encoder.layers.2.linear1.weight',
#  'model.encoder.encoder.layers.2.linear1.bias',
#  'model.encoder.encoder.layers.2.linear2.weight',
#  'model.encoder.encoder.layers.2.linear2.bias',
#  'model.encoder.encoder.layers.2.norm1.weight',
#  'model.encoder.encoder.layers.2.norm1.bias',
#  'model.encoder.encoder.layers.2.norm2.weight',
#  'model.encoder.encoder.layers.2.norm2.bias',
#  'model.encoder.encoder.layers.3.self_attn.in_proj_weight',
#  'model.encoder.encoder.layers.3.self_attn.in_proj_bias',
#  'model.encoder.encoder.layers.3.self_attn.out_proj.weight',
#  'model.encoder.encoder.layers.3.self_attn.out_proj.bias',
#  'model.encoder.encoder.layers.3.linear1.weight',
#  'model.encoder.encoder.layers.3.linear1.bias',
#  'model.encoder.encoder.layers.3.linear2.weight',
#  'model.encoder.encoder.layers.3.linear2.bias',
#  'model.encoder.encoder.layers.3.norm1.weight',
#  'model.encoder.encoder.layers.3.norm1.bias',
#  'model.encoder.encoder.layers.3.norm2.weight',
#  'model.encoder.encoder.layers.3.norm2.bias',
#  'model.fc1.weight',
#  'model.fc1.bias']
