# %%
from torchvision import datasets, transforms, models
import torch.optim as optim
from torch.optim import lr_scheduler
import time
import os
import copy
import torchvision.transforms as T
import torch

from PIL import Image
import requests

import matplotlib.pyplot as plt
import numpy as np
import torch.nn.functional as F
from torch import nn

# %%
from models.backbone import Backbone, EmbeddingNetwork
from models.encoder import EncoderModule
from models.utils.joiner import *
from models.utils.metrics import *
from models.utils.losses import *
from models.unet import UNet

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
H = 320
W= 320

transform = T.Compose([
T.Resize((H,W)),
T.ToTensor(),
T.Normalize([0.485, 0.456, 0.406], [0.485, 0.456, 0.406])
])

# %%
training_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
validation_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=10, shuffle=True)
validation_loader = torch.utils.data.DataLoader(validation_dataset, batch_size = 10, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def im_convert(tensor):
  image = tensor.cpu().clone().detach().numpy()
  image = image.transpose(1, 2, 0)
  image = image * np.array((0.5, 0.5, 0.5)) + np.array((0.5, 0.5, 0.5))
  image = image.clip(0, 1)
  return image

# %%
dataiter = iter(training_loader)
images, labels = dataiter.next()
fig = plt.figure(figsize=(25, 4))

for idx in np.arange(10):
  ax = fig.add_subplot(2, 10, idx+1, xticks=[], yticks=[])
  plt.imshow(im_convert(images[idx]))
  ax.set_title([labels[idx].item()])

# %%
backbone  = Backbone()

# %%
encoder = EncoderModule(d_model=256)#.to(device)
model = Joiner(backbone, encoder, bypass=False, hidden_dim=256, batch_size=10, image_h=H, image_w=W)

# %%
model = model.to(device)

# %%
#TESTING MODEL ON A SINGLE IMAGE

# %%
url = 'https://ogden_images.s3.amazonaws.com/www.timesrepublican.com/images/2019/05/02231710/Fox-WEB-1100x739.jpg'

im = Image.open(requests.get(url, stream=True).raw)
plt.plot()
plt.imshow(im)

# %%
img = transform(im).unsqueeze(0)
print("Input shape:", img.shape)
# Out:
# Input shape: torch.Size([1, 3, 320, 320])

# %%
outputs = backbone(img)

# %%
print("Output shape:", outputs.shape)
#print("Feature Map shape:", f_map.shape)
#print("Attention Maps shape:", sattn.shape)
#print("Encoder output shape:", att.shape)
#print("Positional Encoding shape:", pos.shape)
# Out:
# Output shape: torch.Size([1, 256, 20, 20])

# %%
#Training Model

# %%
#def add_noise(inputs):
#    noise = torch.randn_like(inputs)*0.2
#    return inputs + noise

# %%
add_noise = UNet(3,3,bilinear=False)
add_noise = add_noise.to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.0001)
model_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=9, gamma=0.1)

# %%
gen_criterion = Generator_loss(beta=0.0001, gamma=0.01,sigma=1)
gen_optimizer = torch.optim.Adam(add_noise.parameters(), lr = 0.0001)
gen_lr_scheduler = lr_scheduler.StepLR(gen_optimizer, step_size=6, gamma=0.1)

# %%
epochs = 36
running_loss_history = [] # training loss - to generate a plot
running_gen_loss_history = []
running_corrects_history = [] # traning accuracy
running_noised_corrects_history = [] # traning accuracy
val_running_loss_history = [] # validation loss
val_running_corrects_history = [] # validation accuracy
val_running_noised_loss_history = [] # validation loss
val_running_noised_corrects_history = [] # validation accuracy

for e in range(epochs):
  
    start_time = time.time()
    print('-' * 10)
    print('Epoch {}/{}'.format(e+1, epochs))
    print('-' * 10)
    
    best_model_wts = model.state_dict()
    best_val_acc = 0
    
    running_loss = 0.0
    running_gen_loss = 0.0
    running_corrects = 0.0
    running_noised_corrects = 0.0
    val_running_loss = 0.0
    val_running_corrects = 0.0
    val_noised_running_loss = 0.0
    val_noised_running_corrects = 0.0

    for inputs, labels in training_loader:
        
        #TRAINING THE MODEL
        
        inputs = inputs.to(device) # allow gpu use
        labels = labels.to(device) # allow gpu use
        outputs, _, _ = model(inputs) #gives the output of the last layer
        real_loss = criterion(outputs, labels) # comparing outputs and labels using the criteria
        
        noised_inputs = add_noise(inputs) # allow gpu use
        noised_outputs, _, _ = model(noised_inputs) #gives the output of the last layer
        noised_loss = criterion(noised_outputs, labels) # comparing outputs and labels using the criteria

        loss = real_loss + noised_loss
        
        optimizer.zero_grad() #zero the grad
        loss.backward() #backpropagation
        optimizer.step() #optimize weights 

        _, preds = torch.max(outputs, 1) # return the index of the maximum value predicted for that image (used to generate the accuracy)
        _, noise_preds = torch.max(noised_outputs, 1)
        running_loss += loss.item() # the sum of the loss of all itens
        running_corrects += torch.sum(preds == labels.data) # the sum of correct prediction on an epochs
        running_noised_corrects += torch.sum(noise_preds == labels.data) # the sum of correct prediction on an epochs
        
        Typenone = 0
        zeros = 0
        normal = 0
        for name, param in model.named_parameters():
            if param.grad == None:
                Typenone +=1
            elif torch.sum(param.grad) == 0:
                zeros += 1
            else:
                normal += 1
        if Typenone >10:
            print("None parameters:",Typenone)
            for name, param in model.named_parameters():
                if param.grad == None:
                    print(name)
        if zeros > 5:
            print("Zero Grad Parameters:", zeros)
        
        
        #TRAINING THE GENERATOR
        
        noised_inputs = add_noise(inputs)
        noised_outputs, _, noised_pattn = model(noised_inputs)
        model_loss = criterion(noised_outputs, labels)
        gen_loss = gen_criterion(noised_pattn, noised_inputs, inputs, model_loss)
        
        gen_optimizer.zero_grad()
        gen_loss.backward()
        gen_optimizer.step()
        
        running_gen_loss += gen_loss.item()
                
    else:
        #VALIDATION
        with torch.no_grad(): # to save memory (temporalely set all the requires grad to be false)
            for val_inputs, val_labels in validation_loader:
                val_inputs = val_inputs.to(device) # allow gpu use
                noised_val_inputs = add_noise(val_inputs) # allow gpu use
                val_labels = val_labels.to(device) # allow gpu use
                val_outputs, _, _ = model(val_inputs) #passes the image through the network and get the output
                val_loss = criterion(val_outputs, val_labels) #compare output and labels to get the loss 

                _, val_preds = torch.max(val_outputs, 1) #same as for training
                val_running_loss += val_loss.item() #same as for training
                val_running_corrects += torch.sum(val_preds == val_labels.data) #same as for training
                
                val_noised_outputs, _, _ = model(noised_val_inputs) #passes the image through the network and get the output
                val_noised_loss = criterion(val_noised_outputs, val_labels) #compare output and labels to get the loss 

                _, val_noised_preds = torch.max(val_noised_outputs, 1) #same as for training
                val_noised_running_loss += val_noised_loss.item() #same as for training
                val_noised_running_corrects += torch.sum(val_noised_preds == val_labels.data) #same as for training

                
    model_lr_scheduler.step()
    gen_lr_scheduler.step()
    
    #TRAINING LOSS AND ACCURACY
    epoch_loss = running_loss/len(training_dataset) # the sum of the loss of all itens divided by the number of itens
    gen_epoch_loss = running_gen_loss/len(training_dataset)
    epoch_acc = running_corrects.float()/ len(training_dataset) # the sum of correct predictions divided by the number of itens
    epoch_noised_acc = running_noised_corrects.float()/ len(training_dataset)
    running_loss_history.append(epoch_loss) #append to respective list
    running_gen_loss_history.append(gen_epoch_loss)
    running_corrects_history.append(epoch_acc) #append to respective list
    running_noised_corrects_history.append(epoch_noised_acc) #append to respective list

    #VALIDATION LOSS AND ACCURACY
    val_epoch_loss = val_running_loss/len(validation_dataset)
    val_noised_epoch_loss = val_noised_running_loss/len(validation_dataset)
    val_epoch_acc = val_running_corrects.float()/ len(validation_dataset)
    val_noised_epoch_acc = val_noised_running_corrects.float()/ len(validation_dataset)
    val_running_loss_history.append(val_epoch_loss) #append to respective list
    val_running_corrects_history.append(val_epoch_acc) #append to respective list
    val_running_noised_loss_history.append(val_noised_epoch_loss) #append to respective list
    val_running_noised_corrects_history.append(val_noised_epoch_acc) #append to respective list
    epoch_time_elapsed = time.time() - start_time
    
    if val_epoch_acc > best_val_acc:
        best_model_wts = model.state_dict()
    
    print('Epoch training complete in {:.0f}m {:.0f}s'.format(
            epoch_time_elapsed // 60, epoch_time_elapsed % 60))
    print('training loss: {:.4f}, acc {:.4f}, noised acc {:.4f} '.format(epoch_loss, epoch_acc.item(), epoch_noised_acc.item()))
    print('Generator loss: {:.4f}'.format(gen_epoch_loss))
    print('validation loss: {:.4f}, validation acc {:.4f} '.format(val_epoch_loss, val_epoch_acc.item()))
    print('validation noised loss: {:.4f}, validation noised acc {:.4f} '.format(val_noised_epoch_loss, val_noised_epoch_acc.item()))
# Out:
# ----------
# Epoch 1/36
# ----------
# Epoch training complete in 37m 3s
# training loss: 0.4237, acc 0.3606, noised acc 0.3436
# Generator loss: 0.0223
# validation loss: 0.1730, validation acc 0.4571
# validation noised loss: 0.1929, validation noised acc 0.3906
# ----------
# Epoch 2/36
# ----------
# Epoch training complete in 37m 7s
# training loss: 0.3297, acc 0.4730, noised acc 0.3986
# Generator loss: 0.0230
# validation loss: 0.1352, validation acc 0.5296
# validation noised loss: 0.1686, validation noised acc 0.4136
# ----------
# Epoch 3/36
# ----------
# Epoch training complete in 37m 8s
# training loss: 0.3036, acc 0.5278, noised acc 0.4058
# Generator loss: 0.0231
# validation loss: 0.1354, validation acc 0.5068
# validation noised loss: 0.1713, validation noised acc 0.3858
# ----------
# Epoch 4/36
# ----------
# Epoch training complete in 37m 5s
# training loss: 0.2863, acc 0.5747, noised acc 0.4172
# Generator loss: 0.0235
# validation loss: 0.1204, validation acc 0.5721
# validation noised loss: 0.1665, validation noised acc 0.4101
# ----------
# Epoch 5/36
# ----------
# Epoch training complete in 37m 4s
# training loss: 0.2705, acc 0.6154, noised acc 0.4331
# Generator loss: 0.0240
# validation loss: 0.1181, validation acc 0.5891
# validation noised loss: 0.1734, validation noised acc 0.3988
# ----------
# Epoch 6/36
# ----------
# Epoch training complete in 37m 3s
# training loss: 0.2587, acc 0.6503, noised acc 0.4445
# Generator loss: 0.0249
# validation loss: 0.1162, validation acc 0.5953
# validation noised loss: 0.1664, validation noised acc 0.4209
# ----------
# Epoch 7/36
# ----------
# Epoch training complete in 37m 2s
# training loss: 0.2335, acc 0.6889, noised acc 0.4950
# Generator loss: 0.0256
# validation loss: 0.1135, validation acc 0.6035
# validation noised loss: 0.1614, validation noised acc 0.4415
# ----------
# Epoch 8/36
# ----------
# Epoch training complete in 36m 60s
# training loss: 0.2004, acc 0.7398, noised acc 0.5607
# Generator loss: 0.0265
# validation loss: 0.1175, validation acc 0.6068
# validation noised loss: 0.1646, validation noised acc 0.4497
# ----------
# Epoch 9/36
# ----------
# Epoch training complete in 36m 59s
# training loss: 0.1697, acc 0.7907, noised acc 0.6179
# Generator loss: 0.0272
# validation loss: 0.1194, validation acc 0.6165
# validation noised loss: 0.1648, validation noised acc 0.4735
# ----------
# Epoch 10/36
# ----------
# Epoch training complete in 36m 60s
# training loss: 0.1071, acc 0.9160, noised acc 0.7193
# Generator loss: 0.0276
# validation loss: 0.1365, validation acc 0.6186
# validation noised loss: 0.2007, validation noised acc 0.4307
# ----------
# Epoch 11/36
# ----------
# Epoch training complete in 36m 58s
# training loss: 0.1050, acc 0.9378, noised acc 0.7057
# Generator loss: 0.0278
# validation loss: 0.1464, validation acc 0.6152
# validation noised loss: 0.2119, validation noised acc 0.4244
# ----------
# Epoch 12/36
# ----------
# Epoch training complete in 36m 57s
# training loss: 0.1035, acc 0.9465, noised acc 0.7045
# Generator loss: 0.0279
# validation loss: 0.1524, validation acc 0.6140
# validation noised loss: 0.2173, validation noised acc 0.4231
# ----------
# Epoch 13/36
# ----------
# Epoch training complete in 36m 54s
# training loss: 0.0916, acc 0.9543, noised acc 0.7352
# Generator loss: 0.0281
# validation loss: 0.1598, validation acc 0.6155
# validation noised loss: 0.2058, validation noised acc 0.4538
# ----------
# Epoch 14/36
# ----------
# Epoch training complete in 36m 55s
# training loss: 0.0693, acc 0.9631, noised acc 0.8000
# Generator loss: 0.0283
# validation loss: 0.1724, validation acc 0.6120
# validation noised loss: 0.2088, validation noised acc 0.4870
# ----------
# Epoch 15/36
# ----------
# Epoch training complete in 36m 55s
# training loss: 0.0533, acc 0.9709, noised acc 0.8464
# Generator loss: 0.0284
# validation loss: 0.1912, validation acc 0.6178
# validation noised loss: 0.2202, validation noised acc 0.5039
# ----------
# Epoch 16/36
# ----------
# Epoch training complete in 36m 55s
# training loss: 0.0416, acc 0.9775, noised acc 0.8786
# Generator loss: 0.0285
# validation loss: 0.2041, validation acc 0.6107
# validation noised loss: 0.2282, validation noised acc 0.5137
# ----------
# Epoch 17/36
# ----------
# Epoch training complete in 36m 55s
# training loss: 0.0335, acc 0.9819, noised acc 0.9014
# Generator loss: 0.0285
# validation loss: 0.2255, validation acc 0.6085
# validation noised loss: 0.2443, validation noised acc 0.5194
# ----------
# Epoch 18/36
# ----------
# Epoch training complete in 36m 54s
# training loss: 0.0266, acc 0.9861, noised acc 0.9216
# Generator loss: 0.0285
# validation loss: 0.2375, validation acc 0.6103
# validation noised loss: 0.2547, validation noised acc 0.5331
# ----------
# Epoch 19/36
# ----------
# Epoch training complete in 36m 54s
# training loss: 0.0183, acc 0.9930, noised acc 0.9462
# Generator loss: 0.0285
# validation loss: 0.2452, validation acc 0.6184
# validation noised loss: 0.2651, validation noised acc 0.5326
# ----------
# Epoch 20/36
# ----------
# Epoch training complete in 36m 53s
# training loss: 0.0166, acc 0.9940, noised acc 0.9512
# Generator loss: 0.0285
# validation loss: 0.2509, validation acc 0.6140
# validation noised loss: 0.2700, validation noised acc 0.5370
# ----------
# Epoch 21/36
# ----------
# Epoch training complete in 36m 53s
# training loss: 0.0157, acc 0.9943, noised acc 0.9534
# Generator loss: 0.0285
# validation loss: 0.2544, validation acc 0.6129
# validation noised loss: 0.2723, validation noised acc 0.5308
# ----------
# Epoch 22/36
# ----------
# Epoch training complete in 36m 54s
# training loss: 0.0154, acc 0.9939, noised acc 0.9552
# Generator loss: 0.0285
# validation loss: 0.2591, validation acc 0.6126
# validation noised loss: 0.2743, validation noised acc 0.5371
# ----------
# Epoch 23/36
# ----------
# Epoch training complete in 36m 54s
# training loss: 0.0141, acc 0.9947, noised acc 0.9587
# Generator loss: 0.0285
# validation loss: 0.2619, validation acc 0.6162
# validation noised loss: 0.2779, validation noised acc 0.5408
# ----------
# Epoch 24/36
# ----------
# Epoch training complete in 36m 54s
# training loss: 0.0135, acc 0.9954, noised acc 0.9600
# Generator loss: 0.0285
# validation loss: 0.2670, validation acc 0.6137
# validation noised loss: 0.2794, validation noised acc 0.5423
# ----------
# Epoch 25/36
# ----------
# Epoch training complete in 36m 54s
# training loss: 0.0131, acc 0.9953, noised acc 0.9618
# Generator loss: 0.0285
# validation loss: 0.2648, validation acc 0.6144
# validation noised loss: 0.2824, validation noised acc 0.5394
# ----------
# Epoch 26/36
# ----------
# Epoch training complete in 36m 54s
# training loss: 0.0125, acc 0.9953, noised acc 0.9636
# Generator loss: 0.0285
# validation loss: 0.2697, validation acc 0.6159
# validation noised loss: 0.2878, validation noised acc 0.5345
# ----------
# Epoch 27/36
# ----------
# Epoch training complete in 36m 53s
# training loss: 0.0119, acc 0.9957, noised acc 0.9648
# Generator loss: 0.0285
# validation loss: 0.2736, validation acc 0.6130
# validation noised loss: 0.2868, validation noised acc 0.5387
# ----------
# Epoch 28/36
# ----------
# Epoch training complete in 36m 55s
# training loss: 0.0115, acc 0.9959, noised acc 0.9666
# Generator loss: 0.0285
# validation loss: 0.2719, validation acc 0.6131
# validation noised loss: 0.2890, validation noised acc 0.5433
# ----------
# Epoch 29/36
# ----------
# Epoch training complete in 36m 53s
# training loss: 0.0114, acc 0.9960, noised acc 0.9662
# Generator loss: 0.0285
# validation loss: 0.2741, validation acc 0.6157
# validation noised loss: 0.2873, validation noised acc 0.5481
# ----------
# Epoch 30/36
# ----------
# Epoch training complete in 36m 53s
# training loss: 0.0115, acc 0.9955, noised acc 0.9663
# Generator loss: 0.0285
# validation loss: 0.2726, validation acc 0.6191
# validation noised loss: 0.2865, validation noised acc 0.5438
# ----------
# Epoch 31/36
# ----------
# Epoch training complete in 36m 53s
# training loss: 0.0115, acc 0.9953, noised acc 0.9667
# Generator loss: 0.0285
# validation loss: 0.2739, validation acc 0.6133
# validation noised loss: 0.2868, validation noised acc 0.5429
# ----------
# Epoch 32/36
# ----------
# Epoch training complete in 36m 54s
# training loss: 0.0113, acc 0.9961, noised acc 0.9656
# Generator loss: 0.0285
# validation loss: 0.2764, validation acc 0.6172
# validation noised loss: 0.2892, validation noised acc 0.5405
# ----------
# Epoch 33/36
# ----------
# Epoch training complete in 36m 53s
# training loss: 0.0112, acc 0.9960, noised acc 0.9672
# Generator loss: 0.0285
# validation loss: 0.2732, validation acc 0.6209
# validation noised loss: 0.2912, validation noised acc 0.5413
# ----------
# Epoch 34/36
# ----------
# Epoch training complete in 36m 53s
# training loss: 0.0110, acc 0.9964, noised acc 0.9683
# Generator loss: 0.0285
# validation loss: 0.2744, validation acc 0.6132
# validation noised loss: 0.2895, validation noised acc 0.5402
# ----------
# Epoch 35/36
# ----------
# Epoch training complete in 36m 53s
# training loss: 0.0112, acc 0.9966, noised acc 0.9668
# Generator loss: 0.0285
# validation loss: 0.2749, validation acc 0.6169
# validation noised loss: 0.2911, validation noised acc 0.5436
# ----------
# Epoch 36/36
# ----------
# Epoch training complete in 36m 54s
# training loss: 0.0111, acc 0.9963, noised acc 0.9673
# Generator loss: 0.0285
# validation loss: 0.2767, validation acc 0.6135
# validation noised loss: 0.2901, validation noised acc 0.5438

# %%
cifar_img = training_dataset[123][0].unsqueeze(0)
cifar_img = cifar_img.to(device)
cifar_noised = add_noise(cifar_img)
outputs2, sattn2, pattn2 = model(cifar_img)
sattn2 = sattn2.reshape(1,30,30,30,30)
outputs_noised, sattn_noised, pattn_noised = model(cifar_noised)
sattn_noised = sattn_noised.reshape(1,30,30,30,30)
msloss = nn.MSELoss()
print("Penalized self attention:",torch.sum(pattn2)*0.0001)
print("L2 Recreation loss",msloss(cifar_noised[0],cifar_img[0])*1)
# Out:
# Penalized self attention: tensor(0.2867, device='cuda:0', grad_fn=<MulBackward0>)
# L2 Recreation loss tensor(0.0177, device='cuda:0', grad_fn=<MulBackward0>)

# %%
pix_h = 25
pix_w = 15
threshold = torch.sum(sattn2[0,pix_h,pix_w,...])/180#6.3665e-38
threshold_noised = torch.sum(sattn_noised[0,pix_h,pix_w,...])/150#6.3665e-38
plt.subplot(221)
plt.imshow(cifar_img[0].cpu().permute(1, 2, 0))
plt.subplot(222)
plt.imshow(cifar_noised[0].cpu().detach().permute(1, 2, 0))
plt.subplot(223)
plt.imshow(sattn2[0,pix_h,pix_w,...].cpu().detach().numpy(),cmap='cividis', interpolation='nearest',vmax=threshold)
plt.subplot(224)
plt.imshow(sattn_noised[0,pix_h,pix_w,...].cpu().detach().numpy(),vmax=threshold_noised)
#plt.subplot(222)
#plt.imshow((cifar_img[0]-cifar_noised[0]).cpu().detach().permute(1, 2, 0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
model.load_state_dict(best_model_wts)
torch.save(model.state_dict(),'test/Generator_Encoder_no_bypass_CIFAR10_2.pth')

# %%
msloss = nn.MSELoss()
print(torch.sum(pattn2))
print(msloss(cifar_noised[0],cifar_img[0]))
# Out:
# tensor(2878.8882, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0177, device='cuda:0', grad_fn=<MseLossBackward>)

# %%
outputs, sattn, pattn = model(img.to(device))

# %%
pix_h = 10
pix_w = 13
threshold = torch.sum(sattn[0,pix_h,pix_w,...])/180#6.3665e-38
plt.subplot(221)
plt.imshow(img[0].cpu().permute(1, 2, 0))
plt.subplot(223)
plt.imshow(sattn[0,pix_h,pix_w,...].cpu().detach().numpy(),cmap='cividis', interpolation='nearest',vmax=threshold)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
