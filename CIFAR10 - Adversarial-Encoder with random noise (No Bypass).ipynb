# %%
from torchvision import datasets, transforms, models
import torch.optim as optim
from torch.optim import lr_scheduler
import time
import os
import copy
import torchvision.transforms as T
import torch

from PIL import Image
import requests

import matplotlib.pyplot as plt
import numpy as np
import torch.nn.functional as F
from torch import nn

# %%
from models.backbone import Backbone, EmbeddingNetwork
from models.encoder import EncoderModule
from models.joiner import Joiner
from models.losses import Attention_penalty_factor, Generator_loss
from models.unet import UNet

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
H = 30
W= 30

transform = T.Compose([
T.Resize((H,W)),
T.ToTensor(),
T.Normalize([0.485, 0.456, 0.406], [0.485, 0.456, 0.406])
])

# %%
training_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
validation_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=10, shuffle=True)
validation_loader = torch.utils.data.DataLoader(validation_dataset, batch_size = 10, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def im_convert(tensor):
  image = tensor.cpu().clone().detach().numpy()
  image = image.transpose(1, 2, 0)
  image = image * np.array((0.5, 0.5, 0.5)) + np.array((0.5, 0.5, 0.5))
  image = image.clip(0, 1)
  return image

# %%
dataiter = iter(training_loader)
images, labels = dataiter.next()
fig = plt.figure(figsize=(25, 4))

for idx in np.arange(10):
  ax = fig.add_subplot(2, 10, idx+1, xticks=[], yticks=[])
  plt.imshow(im_convert(images[idx]))
  ax.set_title([labels[idx].item()])

# %%
backbone  = EmbeddingNetwork()
encoder = EncoderModule(d_model=256)#.to(device)
model = Joiner(backbone, encoder, bypass=False, hidden_dim=256, batch_size=10, image_h=H, image_w=W)

# %%
model = model.to(device)

# %%
#TESTING MODEL ON A SINGLE IMAGE

# %%
url = 'https://ogden_images.s3.amazonaws.com/www.timesrepublican.com/images/2019/05/02231710/Fox-WEB-1100x739.jpg'

im = Image.open(requests.get(url, stream=True).raw)
plt.plot()
plt.imshow(im)

# %%
img = transform(im).unsqueeze(0)
print("Input shape:", img.shape)
# Out:
# Input shape: torch.Size([1, 3, 30, 30])

# %%
outputs, sattn, pattn = model(img.to(device))

# %%
print("Output shape:", outputs.shape)
#print("Feature Map shape:", f_map.shape)
print("Attention Maps shape:", sattn.shape)
#print("Encoder output shape:", att.shape)
#print("Positional Encoding shape:", pos.shape)
# Out:
# Output shape: torch.Size([1, 10])
# Attention Maps shape: torch.Size([1, 30, 30, 30, 30])

# %%
#Training Model

# %%
#def add_noise(inputs):
#    noise = torch.randn_like(inputs)*0.2
#    return inputs + noise

# %%
add_noise = UNet(3,3,bilinear=False)
add_noise = add_noise.to(device)

# %%
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr = 0.0001)
model_lr_scheduler = lr_scheduler.StepLR(optimizer, step_size=9, gamma=0.1)

# %%
gen_criterion = Generator_loss()
gen_optimizer = torch.optim.Adam(add_noise.parameters(), lr = 0.0001)
gen_lr_scheduler = lr_scheduler.StepLR(gen_optimizer, step_size=9, gamma=0.1)

# %%
epochs = 36
running_loss_history = [] # training loss - to generate a plot
running_gen_loss_history = []
running_corrects_history = [] # traning accuracy
running_noised_corrects_history = [] # traning accuracy
val_running_loss_history = [] # validation loss
val_running_corrects_history = [] # validation accuracy

for e in range(epochs):
  
    start_time = time.time()
    print('-' * 10)
    print('Epoch {}/{}'.format(e+1, epochs))
    print('-' * 10)
    
    
    running_loss = 0.0
    running_gen_loss = 0.0
    running_corrects = 0.0
    running_noised_corrects = 0.0
    val_running_loss = 0.0
    val_running_corrects = 0.0

    for inputs, labels in training_loader:
        
        #TRAINING THE MODEL
        
        inputs = inputs.to(device) # allow gpu use
        labels = labels.to(device) # allow gpu use
        outputs, _, _ = model(inputs) #gives the output of the last layer
        real_loss = criterion(outputs, labels) # comparing outputs and labels using the criteria
        
        noised_inputs = add_noise(inputs) # allow gpu use
        noised_outputs, _, _ = model(noised_inputs) #gives the output of the last layer
        noised_loss = criterion(noised_outputs, labels) # comparing outputs and labels using the criteria

        loss = real_loss + noised_loss
        
        optimizer.zero_grad() #zero the grad
        loss.backward() #backpropagation
        optimizer.step() #optimize weights 

        _, preds = torch.max(outputs, 1) # return the index of the maximum value predicted for that image (used to generate the accuracy)
        _, noise_preds = torch.max(noised_outputs, 1)
        running_loss += loss.item() # the sum of the loss of all itens
        running_corrects += torch.sum(preds == labels.data) # the sum of correct prediction on an epochs
        running_noised_corrects += torch.sum(noise_preds == labels.data) # the sum of correct prediction on an epochs
        
        Typenone = 0
        zeros = 0
        normal = 0
        for name, param in model.named_parameters():
            if param.grad == None:
                Typenone +=1
            elif torch.sum(param.grad) == 0:
                zeros += 1
            else:
                normal += 1
        if Typenone >10:
            print("None parameters:",Typenone)
            for name, param in model.named_parameters():
                if param.grad == None:
                    print(name)
        if zeros > 5:
            print("Zero Grad Parameters:", zeros)
        
        
        #TRAINING THE GENERATOR
        
        noised_inputs = add_noise(inputs)
        noised_outputs, _, noised_pattn = model(noised_inputs)
        model_loss = criterion(noised_outputs, labels)
        gen_loss = gen_criterion(noised_pattn, noised_inputs, inputs, model_loss)
        
        gen_optimizer.zero_grad()
        gen_loss.backward()
        gen_optimizer.step()
        
        running_gen_loss += gen_loss.item()
                
    else:
        #VALIDATION
        with torch.no_grad(): # to save memory (temporalely set all the requires grad to be false)
            for val_inputs, val_labels in validation_loader:
                val_inputs = val_inputs.to(device) # allow gpu use
                val_labels = val_labels.to(device) # allow gpu use
                val_outputs, val_sattn, val_sattn = model(val_inputs) #passes the image through the network and get the output
                val_loss = criterion(val_outputs, val_labels) #compare output and labels to get the loss 

                _, val_preds = torch.max(val_outputs, 1) #same as for training
                val_running_loss += val_loss.item() #same as for training
                val_running_corrects += torch.sum(val_preds == val_labels.data) #same as for training

                
    model_lr_scheduler.step()
    gen_lr_scheduler.step()
    
    #TRAINING LOSS AND ACCURACY
    epoch_loss = running_loss/len(training_dataset) # the sum of the loss of all itens divided by the number of itens
    gen_epoch_loss = running_gen_loss/len(training_dataset)
    epoch_acc = running_corrects.float()/ len(training_dataset) # the sum of correct predictions divided by the number of itens
    epoch_noised_acc = running_noised_corrects.float()/ len(training_dataset)
    running_loss_history.append(epoch_loss) #append to respective list
    running_gen_loss_history.append(gen_epoch_loss)
    running_corrects_history.append(epoch_acc) #append to respective list
    running_noised_corrects_history.append(epoch_noised_acc) #append to respective list

    #VALIDATION LOSS AND ACCURACY
    val_epoch_loss = val_running_loss/len(validation_dataset)
    val_epoch_acc = val_running_corrects.float()/ len(validation_dataset)
    val_running_loss_history.append(val_epoch_loss) #append to respective list
    val_running_corrects_history.append(val_epoch_acc) #append to respective list
    epoch_time_elapsed = time.time() - start_time
    print('Epoch training complete in {:.0f}m {:.0f}s'.format(
            epoch_time_elapsed // 60, epoch_time_elapsed % 60))
    print('training loss: {:.4f}, acc {:.4f}, noised acc {:.4f} '.format(epoch_loss, epoch_acc.item(), epoch_noised_acc.item()))
    print('Generator loss: {:.4f}'.format(gen_epoch_loss))
    print('validation loss: {:.4f}, validation acc {:.4f} '.format(val_epoch_loss, val_epoch_acc.item()))
# Out:
# Epoch 1/36
# ----------
# Epoch training complete in 35m 19s
# training loss: 0.4024, acc 0.3759, noised acc 0.3623
# Generator loss: 0.0115
# validation loss: 0.1617, validation acc 0.4535
# Epoch 2/36
# ----------
# Epoch training complete in 35m 17s
# training loss: 0.3031, acc 0.4990, noised acc 0.4506
# Generator loss: 0.0117
# validation loss: 0.1292, validation acc 0.5364
# Epoch 3/36
# ----------
# Epoch training complete in 35m 17s
# training loss: 0.2711, acc 0.5606, noised acc 0.4845
# Generator loss: 0.0119
# validation loss: 0.1226, validation acc 0.5657
# Epoch 4/36
# ----------
# Epoch training complete in 35m 14s
# training loss: 0.2534, acc 0.6055, noised acc 0.5037
# Generator loss: 0.0123
# validation loss: 0.1205, validation acc 0.5860
# Epoch 5/36
# ----------
# Epoch training complete in 35m 14s
# training loss: 0.2407, acc 0.6398, noised acc 0.5129
# Generator loss: 0.0127
# validation loss: 0.1215, validation acc 0.5834
# Epoch 6/36
# ----------
# Epoch training complete in 35m 15s
# training loss: 0.2260, acc 0.6761, noised acc 0.5331
# Generator loss: 0.0130
# validation loss: 0.1142, validation acc 0.6088
# Epoch 7/36
# ----------
# Epoch training complete in 35m 16s
# training loss: 0.2102, acc 0.7081, noised acc 0.5515
# Generator loss: 0.0134
# validation loss: 0.1177, validation acc 0.6071
# Epoch 8/36
# ----------
# Epoch training complete in 35m 15s
# training loss: 0.1896, acc 0.7533, noised acc 0.5838
# Generator loss: 0.0136
# validation loss: 0.1158, validation acc 0.6137
# Epoch 9/36
# ----------
# Epoch training complete in 35m 14s
# training loss: 0.1670, acc 0.7956, noised acc 0.6168
# Generator loss: 0.0138
# validation loss: 0.1298, validation acc 0.5845
# Epoch 10/36
# ----------
# Epoch training complete in 35m 15s
# training loss: 0.1304, acc 0.9145, noised acc 0.6672
# Generator loss: 0.0140
# validation loss: 0.1283, validation acc 0.6118
# Epoch 11/36
# ----------
# Epoch training complete in 35m 14s
# training loss: 0.1321, acc 0.9313, noised acc 0.6514
# Generator loss: 0.0141
# validation loss: 0.1316, validation acc 0.6150
# Epoch 12/36
# ----------
# Epoch training complete in 35m 13s
# training loss: 0.1313, acc 0.9385, noised acc 0.6498
# Generator loss: 0.0140
# validation loss: 0.1383, validation acc 0.6026
# Epoch 13/36
# ----------
# Epoch training complete in 35m 14s
# training loss: 0.1289, acc 0.9419, noised acc 0.6501
# Generator loss: 0.0140
# validation loss: 0.1370, validation acc 0.6053
# Epoch 14/36
# ----------
# Epoch training complete in 35m 15s
# training loss: 0.1292, acc 0.9491, noised acc 0.6484
# Generator loss: 0.0141
# validation loss: 0.1394, validation acc 0.6022
# Epoch 15/36
# ----------
# Epoch training complete in 35m 14s
# training loss: 0.1266, acc 0.9538, noised acc 0.6585
# Generator loss: 0.0141
# validation loss: 0.1394, validation acc 0.5988
# Epoch 16/36
# ----------
# Epoch training complete in 35m 14s
# training loss: 0.1237, acc 0.9582, noised acc 0.6619
# Generator loss: 0.0141
# validation loss: 0.1414, validation acc 0.5970
# Epoch 17/36
# ----------
# Epoch training complete in 35m 15s
# training loss: 0.1215, acc 0.9628, noised acc 0.6683
# Generator loss: 0.0141
# validation loss: 0.1406, validation acc 0.5988
# Epoch 18/36
# ----------
# Epoch training complete in 35m 14s
# training loss: 0.1193, acc 0.9681, noised acc 0.6743
# Generator loss: 0.0142
# validation loss: 0.1429, validation acc 0.5949
# Epoch 19/36
# ----------
# Epoch training complete in 35m 22s
# training loss: 0.1257, acc 0.9700, noised acc 0.7631
# Generator loss: 0.0142
# validation loss: 0.1411, validation acc 0.5876
# Epoch 20/36
# ----------
# Epoch training complete in 35m 25s
# training loss: 0.1241, acc 0.9746, noised acc 0.7284
# Generator loss: 0.0142
# validation loss: 0.1333, validation acc 0.5905
# Epoch 21/36
# ----------
# Epoch training complete in 35m 22s
# training loss: 0.1456, acc 0.9698, noised acc 0.7001
# Generator loss: 0.0141
# validation loss: 0.1315, validation acc 0.5881
# Epoch 22/36
# ----------
# Epoch training complete in 35m 22s
# training loss: 0.1537, acc 0.9666, noised acc 0.6545
# Generator loss: 0.0141
# validation loss: 0.1296, validation acc 0.5926
# Epoch 23/36
# ----------
# Epoch training complete in 35m 22s
# training loss: 0.1671, acc 0.9658, noised acc 0.6174
# Generator loss: 0.0140
# validation loss: 0.1249, validation acc 0.6000
# Epoch 24/36
# ----------
# Epoch training complete in 35m 22s
# training loss: 0.1790, acc 0.9633, noised acc 0.5885
# Generator loss: 0.0140
# validation loss: 0.1222, validation acc 0.5987
# Epoch 25/36
# ----------
# Epoch training complete in 35m 21s
# training loss: 0.1854, acc 0.9631, noised acc 0.5623
# Generator loss: 0.0140
# validation loss: 0.1216, validation acc 0.5998
# Epoch 26/36
# ----------
# Epoch training complete in 35m 13s
# training loss: 0.1932, acc 0.9612, noised acc 0.5368
# Generator loss: 0.0139
# validation loss: 0.1191, validation acc 0.6019
# Epoch 27/36
# ----------
# Epoch training complete in 35m 13s
# training loss: 0.1992, acc 0.9596, noised acc 0.5166
# Generator loss: 0.0139
# validation loss: 0.1185, validation acc 0.6052
# Epoch 28/36
# ----------
# Epoch training complete in 35m 12s
# training loss: 0.2248, acc 0.9583, noised acc 0.4950
# Generator loss: 0.0139
# validation loss: 0.1175, validation acc 0.6048
# Epoch 29/36
# ----------
# Epoch training complete in 35m 13s
# training loss: 0.3234, acc 0.9479, noised acc 0.5595
# Generator loss: 0.0138
# validation loss: 0.1190, validation acc 0.5972
# Epoch 30/36
# ----------
# Epoch training complete in 35m 12s
# training loss: 0.2536, acc 0.9419, noised acc 0.5197
# Generator loss: 0.0138
# validation loss: 0.1190, validation acc 0.5938
# Epoch 31/36
# ----------
# Epoch training complete in 35m 12s
# training loss: 0.2531, acc 0.9397, noised acc 0.5023
# Generator loss: 0.0138
# validation loss: 0.1183, validation acc 0.5965
# Epoch 32/36
# ----------
# Epoch training complete in 35m 13s
# training loss: 0.2385, acc 0.9399, noised acc 0.4813
# Generator loss: 0.0138
# validation loss: 0.1168, validation acc 0.6011
# Epoch 33/36
# ----------
# Epoch training complete in 35m 13s
# training loss: 0.2528, acc 0.9339, noised acc 0.4430
# Generator loss: 0.0138
# validation loss: 0.1167, validation acc 0.6019
# Epoch 34/36
# ----------
# Epoch training complete in 35m 13s
# training loss: 0.2536, acc 0.9319, noised acc 0.4138
# Generator loss: 0.0137
# validation loss: 0.1157, validation acc 0.5979
# Epoch 35/36
# ----------
# Epoch training complete in 35m 12s
# training loss: 0.2604, acc 0.9328, noised acc 0.3879
# Generator loss: 0.0137
# validation loss: 0.1154, validation acc 0.6014
# Epoch 36/36
# ----------
# Epoch training complete in 35m 12s
# training loss: 0.2694, acc 0.9279, noised acc 0.3663
# Generator loss: 0.0137
# validation loss: 0.1159, validation acc 0.6071

# %%
cifar_img = training_dataset[131][0].unsqueeze(0)
cifar_img = cifar_img.to(device)
cifar_noised = add_noise(cifar_img)
outputs2, sattn2, pattn2 = model(cifar_img)
sattn2 = sattn2.reshape(1,30,30,30,30)
outputs_noised, sattn_noised, pattn_noised = model(cifar_noised)
sattn_noised = sattn_noised.reshape(1,30,30,30,30)
msloss = nn.MSELoss()
print("Penalized self attention:",torch.sum(pattn2)*0.00005)
print("L2 Recreation loss",msloss(cifar_noised[0],cifar_img[0])*1)
# Out:
# Penalized self attention: tensor(0.1430, device='cuda:0', grad_fn=<MulBackward0>)
# L2 Recreation loss tensor(0.0044, device='cuda:0', grad_fn=<MulBackward0>)

# %%
pix_h = 26
pix_w = 15
threshold = torch.sum(sattn2[0,pix_h,pix_w,...])/180#6.3665e-38
threshold_noised = torch.sum(sattn_noised[0,pix_h,pix_w,...])/150#6.3665e-38
plt.subplot(221)
plt.imshow(cifar_img[0].cpu().permute(1, 2, 0))
plt.subplot(222)
plt.imshow(cifar_noised[0].cpu().detach().permute(1, 2, 0))
plt.subplot(223)
plt.imshow(sattn2[0,pix_h,pix_w,...].cpu().detach().numpy(),cmap='cividis', interpolation='nearest',vmax=threshold)
plt.subplot(224)
plt.imshow(sattn_noised[0,pix_h,pix_w,...].cpu().detach().numpy(),vmax=threshold_noised)
#plt.subplot(222)
#plt.imshow((cifar_noised[0]-cifar_img[0]).cpu().detach().permute(1, 2, 0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
torch.save(model.state_dict(),'test/Generator_Encoder_no_bypass_CIFAR10_2.pth')

# %%
msloss = nn.MSELoss()
print(torch.sum(pattn2))
print(msloss(cifar_noised[0],cifar_img[0]))
# Out:
# tensor(2796.1277, device='cuda:0', grad_fn=<SumBackward0>)
# tensor(0.0048, device='cuda:0', grad_fn=<MseLossBackward>)
