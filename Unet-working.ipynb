# %%
from torchvision import datasets, transforms, models
import torch.optim as optim
from torch.optim import lr_scheduler
import time
import os
import copy
import torchvision.transforms as T
import torch

from PIL import Image
import requests

import matplotlib.pyplot as plt
import numpy as np
import torch.nn.functional as F
from torch import nn

from torchsummary import summary

# %%
from models.backbone import Backbone
from models.encoder import EncoderModule
from models.joiner import Joiner
from models.losses import Attention_penalty_factor
from models.unet import UNet

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda:0

# %%
H = 180
W=180

transform = T.Compose([
T.Resize((H,W)),
T.ToTensor(),
T.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
training_dataset = datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
validation_dataset = datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

training_loader = torch.utils.data.DataLoader(training_dataset, batch_size=10, shuffle=True)
validation_loader = torch.utils.data.DataLoader(validation_dataset, batch_size = 10, shuffle=False)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def im_convert(tensor):
  image = tensor.cpu().clone().detach().numpy()
  image = image.transpose(1, 2, 0)
  image = image * np.array((0.5, 0.5, 0.5)) + np.array((0.5, 0.5, 0.5))
  image = image.clip(0, 1)
  return image

# %%
dataiter = iter(training_loader)
images, labels = dataiter.next()
fig = plt.figure(figsize=(25, 4))

for idx in np.arange(10):
  ax = fig.add_subplot(2, 10, idx+1, xticks=[], yticks=[])
  plt.imshow(im_convert(images[idx]))
  ax.set_title([labels[idx].item()])

# %%
unet = UNet(3,3)
backbone = Backbone().to(device)
encoder = EncoderModule().to(device)
model = Joiner(backbone, encoder, hidden_dim=512, image_h=H, image_w=W)

# %%
unet = unet.to(device)
model = model.to(device)

# %%
#TESTING MODEL ON A SINGLE IMAGE

# %%
url = 'https://ogden_images.s3.amazonaws.com/www.timesrepublican.com/images/2019/05/02231710/Fox-WEB-1100x739.jpg'

im = Image.open(requests.get(url, stream=True).raw)
plt.plot()
plt.imshow(im)

# %%
img = transform(im).unsqueeze(0)
print("Input shape:", img.shape)
# Out:
# Input shape: torch.Size([1, 3, 180, 180])

# %%
outputs, att, sattn, f_map, pos, pattn = model(img.to(device))

# %%
print("Output shape:", outputs.shape)
print("Feature Map shape:", f_map.shape)
print("Attention Maps shape:", sattn.shape)
print("Encoder output shape:", att.shape)
print("Positional Encoding shape:", pos.shape)
# Out:
# Output shape: torch.Size([1, 10])
# Feature Map shape: torch.Size([1, 512, 12, 12])
# Attention Maps shape: torch.Size([1, 12, 12, 12, 12])
# Encoder output shape: torch.Size([1, 512, 12, 12])
# Positional Encoding shape: torch.Size([1, 512, 12, 12])

# %%
summary(unet, input_size=(3, 180, 180))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1         [-1, 64, 180, 180]           1,792
#        BatchNorm2d-2         [-1, 64, 180, 180]             128
#               ReLU-3         [-1, 64, 180, 180]               0
#             Conv2d-4         [-1, 64, 180, 180]          36,928
#        BatchNorm2d-5         [-1, 64, 180, 180]             128
#               ReLU-6         [-1, 64, 180, 180]               0
#         DoubleConv-7         [-1, 64, 180, 180]               0
#          MaxPool2d-8           [-1, 64, 90, 90]               0
#             Conv2d-9          [-1, 128, 90, 90]          73,856
#       BatchNorm2d-10          [-1, 128, 90, 90]             256
#              ReLU-11          [-1, 128, 90, 90]               0
#            Conv2d-12          [-1, 128, 90, 90]         147,584
#       BatchNorm2d-13          [-1, 128, 90, 90]             256
#              ReLU-14          [-1, 128, 90, 90]               0
#        DoubleConv-15          [-1, 128, 90, 90]               0
#              Down-16          [-1, 128, 90, 90]               0
#         MaxPool2d-17          [-1, 128, 45, 45]               0
#            Conv2d-18          [-1, 256, 45, 45]         295,168
#       BatchNorm2d-19          [-1, 256, 45, 45]             512
#              ReLU-20          [-1, 256, 45, 45]               0
#            Conv2d-21          [-1, 256, 45, 45]         590,080
#       BatchNorm2d-22          [-1, 256, 45, 45]             512
#              ReLU-23          [-1, 256, 45, 45]               0
#        DoubleConv-24          [-1, 256, 45, 45]               0
#              Down-25          [-1, 256, 45, 45]               0
#         MaxPool2d-26          [-1, 256, 22, 22]               0
#            Conv2d-27          [-1, 512, 22, 22]       1,180,160
#       BatchNorm2d-28          [-1, 512, 22, 22]           1,024
#              ReLU-29          [-1, 512, 22, 22]               0
#            Conv2d-30          [-1, 512, 22, 22]       2,359,808
#       BatchNorm2d-31          [-1, 512, 22, 22]           1,024
#              ReLU-32          [-1, 512, 22, 22]               0
#        DoubleConv-33          [-1, 512, 22, 22]               0
#              Down-34          [-1, 512, 22, 22]               0
#         MaxPool2d-35          [-1, 512, 11, 11]               0
#            Conv2d-36          [-1, 512, 11, 11]       2,359,808
#       BatchNorm2d-37          [-1, 512, 11, 11]           1,024
#              ReLU-38          [-1, 512, 11, 11]               0
#            Conv2d-39          [-1, 512, 11, 11]       2,359,808
#       BatchNorm2d-40          [-1, 512, 11, 11]           1,024
#              ReLU-41          [-1, 512, 11, 11]               0
#        DoubleConv-42          [-1, 512, 11, 11]               0
#              Down-43          [-1, 512, 11, 11]               0
#          Upsample-44          [-1, 512, 22, 22]               0
#            Conv2d-45          [-1, 512, 22, 22]       4,719,104
#       BatchNorm2d-46          [-1, 512, 22, 22]           1,024
#              ReLU-47          [-1, 512, 22, 22]               0
#            Conv2d-48          [-1, 256, 22, 22]       1,179,904
#       BatchNorm2d-49          [-1, 256, 22, 22]             512
#              ReLU-50          [-1, 256, 22, 22]               0
#        DoubleConv-51          [-1, 256, 22, 22]               0
#                Up-52          [-1, 256, 22, 22]               0
#          Upsample-53          [-1, 256, 44, 44]               0
#            Conv2d-54          [-1, 256, 45, 45]       1,179,904
#       BatchNorm2d-55          [-1, 256, 45, 45]             512
#              ReLU-56          [-1, 256, 45, 45]               0
#            Conv2d-57          [-1, 128, 45, 45]         295,040
#       BatchNorm2d-58          [-1, 128, 45, 45]             256
#              ReLU-59          [-1, 128, 45, 45]               0
#        DoubleConv-60          [-1, 128, 45, 45]               0
#                Up-61          [-1, 128, 45, 45]               0
#          Upsample-62          [-1, 128, 90, 90]               0
#            Conv2d-63          [-1, 128, 90, 90]         295,040
#       BatchNorm2d-64          [-1, 128, 90, 90]             256
#              ReLU-65          [-1, 128, 90, 90]               0
#            Conv2d-66           [-1, 64, 90, 90]          73,792
#       BatchNorm2d-67           [-1, 64, 90, 90]             128
#              ReLU-68           [-1, 64, 90, 90]               0
#        DoubleConv-69           [-1, 64, 90, 90]               0
#                Up-70           [-1, 64, 90, 90]               0
#          Upsample-71         [-1, 64, 180, 180]               0
#            Conv2d-72         [-1, 64, 180, 180]          73,792
#       BatchNorm2d-73         [-1, 64, 180, 180]             128
#              ReLU-74         [-1, 64, 180, 180]               0
#            Conv2d-75         [-1, 64, 180, 180]          36,928
#       BatchNorm2d-76         [-1, 64, 180, 180]             128
#              ReLU-77         [-1, 64, 180, 180]               0
#        DoubleConv-78         [-1, 64, 180, 180]               0
#                Up-79         [-1, 64, 180, 180]               0
#            Conv2d-80          [-1, 3, 180, 180]             195
#           OutConv-81          [-1, 3, 180, 180]               0
# ================================================================
# Total params: 17,267,523
# Trainable params: 17,267,523
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.37
# Forward/backward pass size (MB): 465.03
# Params size (MB): 65.87
# Estimated Total Size (MB): 531.27
# ----------------------------------------------------------------

# %%
out = unet(img.to(device))

# %%
out.shape
# Out:
# torch.Size([1, 3, 180, 180])

# %%
#for inputs, labels in training_loader:
#    print(inputs.requires_grad)

# %%
#Training Model

# %%
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(unet.parameters(), lr = 0.0001)

# %%
epochs = 2
running_loss_history = [] # training loss - to generate a plot
running_corrects_history = [] # traning accuracy
val_running_loss_history = [] # validation loss
val_running_corrects_history = [] # validation accuracy

for e in range(epochs):
  
    running_loss = 0.0
    running_corrects = 0.0
    val_running_loss = 0.0
    val_running_corrects = 0.0

    for inputs, labels in training_loader:
    #TRAINING
        inputs = inputs.to(device) # allow gpu use
        labels = labels.to(device) # allow gpu use
        outputs = unet(inputs) #gives the output of the last layer
        loss = criterion(outputs, inputs) # comparing outputs and labels using the criteria

        optimizer.zero_grad() #zero the grad
        loss.backward() #backpropagation
        optimizer.step() #optimize weights 

        #_, preds = torch.max(outputs, 1) # return the index of the maximum value predicted for that image (used to generate the accuracy)
        running_loss += loss.item() # the sum of the loss of all itens
        #running_corrects += torch.sum(preds == labels.data) # the sum of correct prediction on an epochs

    else:
        #VALIDATION
        with torch.no_grad(): # to save memory (temporalely set all the requires grad to be false)
            for val_inputs, val_labels in validation_loader:
                val_inputs = val_inputs.to(device) # allow gpu use
                val_labels = val_labels.to(device) # allow gpu use
                val_outputs = unet(val_inputs) #passes the image through the network and get the output
                val_loss = criterion(val_outputs, inputs) #compare output and labels to get the loss 

                #_, val_preds = torch.max(val_outputs, 1) #same as for training
                val_running_loss += val_loss.item() #same as for training
                #val_running_corrects += torch.sum(val_preds == val_labels.data) #same as for training

    #TRAINING LOSS AND ACCURACY
    epoch_loss = running_loss/len(training_dataset) # the sum of the loss of all itens divided by the number of itens
    #epoch_acc = running_corrects.float()/ len(training_dataset) # the sum of correct predictions divided by the number of itens
    running_loss_history.append(epoch_loss) #append to respective list
    #running_corrects_history.append(epoch_acc) #append to respective list

    #VALIDATION LOSS AND ACCURACY
    val_epoch_loss = val_running_loss/len(validation_dataset)
    #val_epoch_acc = val_running_corrects.float()/ len(validation_dataset)
    val_running_loss_history.append(val_epoch_loss) #append to respective list
    #val_running_corrects_history.append(val_epoch_acc) #append to respective list
    print('epoch :', (e+1))
    print('training loss: {:.4f} '.format(epoch_loss))
    print('validation loss: {:.4f}'.format(val_epoch_loss))
# Out:
# epoch : 1
# training loss: 0.0000
# validation loss: 0.2195
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-f8e41538a11a> in <module>
#      24
#      25         #_, preds = torch.max(outputs, 1) # return the index of the maximum value predicted for that image (used to generate the accuracy)
# ---> 26         running_loss += loss.item() # the sum of the loss of all itens
#      27         #running_corrects += torch.sum(preds == labels.data) # the sum of correct prediction on an epochs
#      28
#
# KeyboardInterrupt:

# %%
out2 = unet(img.to(device))

# %%
out == out2
# Out:
# tensor([[[[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]],
#
#          [[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]],
#
#          [[False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           ...,
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False],
#           [False, False, False,  ..., False, False, False]]]], device='cuda:0')

# %%
for param in unet.parameters():
    print(param.requires_grad, param.grad.data.sum())
# Out:
# True tensor(4.4676e-05, device='cuda:0')
# True tensor(1.3070e-12, device='cuda:0')
# True tensor(-3.7543e-09, device='cuda:0')
# True tensor(-1.0145e-06, device='cuda:0')
# True tensor(-0.0012, device='cuda:0')
# True tensor(-3.2681e-12, device='cuda:0')
# True tensor(7.0941e-06, device='cuda:0')
# True tensor(1.1561e-07, device='cuda:0')
# True tensor(0.0016, device='cuda:0')
# True tensor(8.4743e-13, device='cuda:0')
# True tensor(-6.0467e-09, device='cuda:0')
# True tensor(6.0729e-07, device='cuda:0')
# True tensor(-1.6311e-05, device='cuda:0')
# True tensor(-3.9779e-13, device='cuda:0')
# True tensor(1.2581e-06, device='cuda:0')
# True tensor(2.7562e-06, device='cuda:0')
# True tensor(2.5901e-05, device='cuda:0')
# True tensor(-1.0358e-13, device='cuda:0')
# True tensor(-4.8608e-09, device='cuda:0')
# True tensor(8.6149e-07, device='cuda:0')
# True tensor(-0.0004, device='cuda:0')
# True tensor(-5.3785e-13, device='cuda:0')
# True tensor(1.0761e-06, device='cuda:0')
# True tensor(3.0390e-06, device='cuda:0')
# True tensor(0.0005, device='cuda:0')
# True tensor(6.0257e-14, device='cuda:0')
# True tensor(-6.1305e-09, device='cuda:0')
# True tensor(2.3908e-06, device='cuda:0')
# True tensor(0.0004, device='cuda:0')
# True tensor(4.1633e-15, device='cuda:0')
# True tensor(6.6419e-07, device='cuda:0')
# True tensor(4.7611e-06, device='cuda:0')
# True tensor(0.0005, device='cuda:0')
# True tensor(1.3917e-13, device='cuda:0')
# True tensor(-5.2294e-09, device='cuda:0')
# True tensor(4.9147e-06, device='cuda:0')
# True tensor(0.0021, device='cuda:0')
# True tensor(1.7633e-13, device='cuda:0')
# True tensor(-6.7517e-07, device='cuda:0')
# True tensor(3.1649e-06, device='cuda:0')
# True tensor(0.0048, device='cuda:0')
# True tensor(-5.0293e-14, device='cuda:0')
# True tensor(-2.2302e-08, device='cuda:0')
# True tensor(2.7232e-06, device='cuda:0')
# True tensor(0.0033, device='cuda:0')
# True tensor(-1.4060e-13, device='cuda:0')
# True tensor(-1.0913e-06, device='cuda:0')
# True tensor(9.3446e-07, device='cuda:0')
# True tensor(0.0069, device='cuda:0')
# True tensor(-4.9499e-13, device='cuda:0')
# True tensor(-5.0946e-08, device='cuda:0')
# True tensor(1.8635e-06, device='cuda:0')
# True tensor(-0.0121, device='cuda:0')
# True tensor(-7.2159e-13, device='cuda:0')
# True tensor(-1.3028e-06, device='cuda:0')
# True tensor(-1.0647e-06, device='cuda:0')
# True tensor(-0.0056, device='cuda:0')
# True tensor(-4.9494e-13, device='cuda:0')
# True tensor(-2.4589e-08, device='cuda:0')
# True tensor(-2.5138e-07, device='cuda:0')
# True tensor(0.0064, device='cuda:0')
# True tensor(1.2236e-12, device='cuda:0')
# True tensor(-6.9848e-06, device='cuda:0')
# True tensor(2.7332e-06, device='cuda:0')
# True tensor(-0.0008, device='cuda:0')
# True tensor(7.2482e-12, device='cuda:0')
# True tensor(-6.6539e-07, device='cuda:0')
# True tensor(-0.0001, device='cuda:0')
# True tensor(-0.0894, device='cuda:0')
# True tensor(6.4926e-12, device='cuda:0')
# True tensor(-0.0002, device='cuda:0')
# True tensor(-0.0006, device='cuda:0')
# True tensor(-0.0143, device='cuda:0')
# True tensor(-0.0026, device='cuda:0')

# %%
plt.subplot(221)
plt.imshow(img[0].cpu().permute(1, 2, 0))
plt.subplot(222)
plt.imshow(out[0].cpu().detach().permute(1, 2, 0))
plt.subplot(223)
plt.imshow(out2[0].cpu().detach().permute(1, 2, 0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
